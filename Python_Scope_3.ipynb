# %% [markdown]
# <a href="https://colab.research.google.com/github/digitechit07/Python-Tutorial-with-Excercise/blob/main/Python_Scope_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Scope in Python**
#
# Last Updated OnFebruary 28, 2025ByScientech EasyInPythonRead Time6 mins
# Using a function defines the concept of scope in Python. If we define a variable inside a function or pass a value to a function’s parameter, the value of that variable is only really accessible within that function. This is called scope.
#
# In other words, the scope is the region of a program where we can access a particular identifier or variable. This is called scope of variable or simply variable scope.
#
# Variables declared inside a program may not be accessible at all locations of that program. It depends on the where we have declared a variable in a program.
#
# Most variables that we define in Python are local in scope to their own function or class. Consider the following example code below.

# %%
a = 0

def my_function():
    a = 3
    print(a)

my_function()

print(a)


def my_function(a):
    b = a - 2
    return b

c = 3

if c > 2:
    d = my_function(5)
    print(d)

# this is a list of numbers
my_list = [1, 2, 3]
my_list[0] = 5 # we can change just the first element of the list
print(my_list)

class MyClass(object):
    pass # this is a very silly class

# Now we make a very simple object using our class as a type
my_object = MyClass()

# We can change the values of attributes on the object
my_object.some_property = 42

def showMe(msg): # function header with one formal parameter.
    print(msg) # local scope.

# Main program.
msg = showMe('Hi John, Good Morning!')
print(msg) # being local variable, it does not exist outside the function.


x = 10

# accessible here
print(x)

if True:
    # accessible inside a block
    print('Inside an if block', x)

def print_num():
    # accessible inside a function
    print('Inside a function:', x)

print_num()

def func1():
    x = 10
    print('Inside func1():', x)

    def func2():
        print('Inside func2():', x)

    func2()

func1()

def func1():
    def func2():
        x = 'local'
        print(x)
    func2()

func1()

x = 'global'

def func1():
    def func2():
        print(x)
    func2()

func1()

def func1():
    def func2():
        print(str)
    func2()

func1()

def func1():
    def func2():
        print(str)
    func2()

func1()


x = 10 # Global variable

def my_function():
    print("Inside the function, the value of x is:", x)

my_function()
# Output: Inside the function, the value of x is: 10

print("Outside the function, the value of x is:", x)
# Output: Outside the function, the value of x is: 10

def my_function():
    x = 20 # Local variable
    print("Inside the function, the value of x is:", x)

my_function()
# Output: Inside the function, the value of x is: 20

print("Outside the function, the value of x is:", x)
# Raises an error: NameError: name 'x' is not defined

def local_scope_example():
    local_var = "I am local!"
    print(local_var)

local_scope_example()
'''
try:
    print(local_var)  # This will raise an error
except NameError as e:
    print(e)

def outer_function():
  enclosing_var = "I am in the enclosing scope"

def inner_function():
  print(enclosing_var)

  inner_function()

outer_function()
'''
global_var = "I am global!"

def global_scope_example():
    print(global_var)

global_scope_example()
print(global_var)

# Using the built-in `len` function from the built-in scope
my_list = [1, 2, 3]
print(len(my_list))

counter = 0

def increase_counter():
    global counter
    counter += 1

increase_counter()
print(counter)

def outer_function():
    count = 0

    def inner_function():
        nonlocal count
        count += 1
        print(count)

    inner_function()
    print("Count in outer:", count)

outer_function()

test_string = "local scope"
def test_local_scope():
    test_string = "local scope"
    print("executed from function: " + test_string)


test_local_scope()

print("executed globally: " + test_string)

test_string = "Global scope."

def test_global_scope():
    print("Executed from function: " + test_string)



test_string = "Global scope."

def test_global_scope():
#    print("Executed from function: " + test_string)
    test_string = "Local scope."


test_global_scope()

test_string = "Global scope."

def test_global_scope():
    test_string = "Local scope."
    print("Executed from function: " + test_string)


test_global_scope()
print("Executed globally: " + test_string)
# Out:
# 3
# 0
# 3
# [5, 2, 3]
# Hi John, Good Morning!
# None
# 10
# Inside an if block 10
# Inside a function: 10
# Inside func1(): 10
# Inside func2(): 10
# local
# global
# <class 'str'>
# <class 'str'>
# Inside the function, the value of x is: 10
# Outside the function, the value of x is: 10
# Inside the function, the value of x is: 20
# Outside the function, the value of x is: 10
# I am local!
# I am global!
# I am global!
# 3
# 1
# 1
# Count in outer: 1
# executed from function: local scope
# executed globally: local scope
# Executed from function: Local scope.
# Executed globally: Global scope.

# %% [markdown]
# # **Variable Scope and Lifetime in Python**
# The scope of variable is a region of the program where a variable is visible or accessible. Lifetime of a variable is the duration for which a variable exists in the memory. The existence and accessibility depend on the declaration of a variable in the program.
#
# For example, the lifetime of a variable declared inside a function is as long as the function is alive. When the execution of function body is finished, then the variable defined inside a function will destroy.

# %%
def myfunc():
  x = 300
  print(x)

myfunc()

def myfunc():
  x = 300
  def myinnerfunc():
    print(x)
  myinnerfunc()

myfunc()

x = 300

def myfunc():
  print(x)

myfunc()

print(x)


def myfunc():
  global x
  x = 300

myfunc()

print(x)

x = 300

def myfunc():
  global x
  x = 200

myfunc()

print(x)

def greet():
    message = "Hello, Python learner!"
    print(message)

greet()

def outer_function():
    teacher = "Guido"

    def inner_function():
        student = "You"
        print("Teacher:", teacher)
        print("Student:", student)

    inner_function()

outer_function()

teacher = "Guido"

def greet_student():
    print("Your teacher is", teacher)

greet_student()
print("Global teacher:", teacher)

counter = 0

def update_counter():
    global counter
    counter += 1

update_counter()
print("Counter is now", counter)

def example():
    x = "I'm Local"
    print(x)

example()  # Output: I'm Local

def outer():
    x = "I'm Enclosing"
    def inner():
        print(x)
    inner()

outer()  # Output: I'm Enclosing

x = "I'm Global"

def show():
    print(x)

show()  # Output: I'm Global

def show_len():
    print(len("Python"))  # Output: 6

#len = 5  # Bad idea!
#print(len("test"))  # ❌ Error: 'int' object is not callable

print(x)


x = "global"

def outer():
    x = "enclosing"
    def inner():
        x = "local"
        print("Inner:", x)
    inner()
    print("Outer:", x)

outer()
print("Global:", x)

def greet():
    name = "Alice"
    print("Hello", name)

greet()
# print(name)  # ❌ This will cause an error: name is not defined

name = "Bob"  # global

def greet():
    print("Hello", name)


count = 10

def update():
    count = count + 1  # ❌ Error: UnboundLocalError
    print(count)

#update()

score = 0

def increase():
    global score
    score += 1

increase()
print(score)  # ✅ Output: 1


total = 0

def add(n):
    global total
    total += n


def add(total, n):
    return total + n


def outer():
    x = 10
    def inner():
        nonlocal x
        x += 5
        print("Inner:", x)
    inner()
    print("Outer:", x)

outer()

x = "global"

def outer():
    x = "enclosing"

    def inner():
        nonlocal x
        x = "modified"
        print("Inner:", x)

    inner()
    print("Outer:", x)

outer()
print("Global:", x)


balance = 1000  # Global variable

def deposit(amount):
    global balance
    balance += amount
    print(f"Deposited {amount}. New balance: {balance}")

def withdraw(amount):
    global balance
    if balance >= amount:
        balance -= amount
        print(f"Withdrew {amount}. New balance: {balance}")
    else:
        print("Insufficient funds.")

deposit(500)
withdraw(300)
withdraw(1500)
# Out:
# 300
# 300
# 300
# 300
# 300
# 200
# Hello, Python learner!
# Teacher: Guido
# Student: You
# Your teacher is Guido
# Global teacher: Guido
# Counter is now 1
# I'm Local
# I'm Enclosing
# I'm Global
# I'm Global
# Inner: local
# Outer: enclosing
# Global: global
# Hello Alice
# 1
# Inner: 15
# Outer: 15
# Inner: modified
# Outer: modified
# Global: global
# Deposited 500. New balance: 1500
# Withdrew 300. New balance: 1200
# Insufficient funds.

# %% [markdown]
# # **Types of Scope of Variables in Python**
# There are two basic types of scope of variables in Python. They are:
#
# Global scope
# Local scope

# %%
def deposit(balance, amount):
    balance += amount
    print(f"Deposited {amount}. New balance: {balance}")
    return balance

def withdraw(balance, amount):
    if balance >= amount:
        balance -= amount
        print(f"Withdrew {amount}. New balance: {balance}")
    else:
        print("Insufficient funds.")
    return balance

balance = 1000
balance = deposit(balance, 500)
balance = withdraw(balance, 300)
balance = withdraw(balance, 1500)

x = 100

def func():
    print(x)
    x = 10

#func()

total = 10

def change():
    total += 5  # Error!


def change():
    global total
    total += 5

x = 5

def demo():
    x = 10
    print(x)

demo()        # 10
print(x)      # 5

x = 100

def test():
    x = 200
    print(x)

test()
print(x)

x = 10
def func():
    print(x)
x = 20
func()

nums = [1, 2, 3]

def add_item():
    nums.append(4)

add_item()
print(nums)  # ✅ Output: [1, 2, 3, 4]

def outer():
    x = "hello"
    def inner():
        nonlocal x
        x = "world"
    inner()
    print(x)

outer()

def something():
   localVar = 1

# this will crash because localVar is a local variable
#print(localVar)


balance = 0

def addAmount(x):
    global balance
    balance = balance + x

addAmount(5)
print(balance)

x = 10   # global variable

def foo():
    print(x)   # accesses the global variable x

foo()   # prints 10

def foo():
    x = 20   # local variable
    print(x)   # prints 20

foo()   # prints 20
print(x)   # generates an error because x is not defined in the global scope

def outer():
    x = 10   # variable defined in the enclosing scope

    def inner():
        print(x)   # accesses the variable x defined in the enclosing scope

    inner()

outer()   # prints 10


def outer():
    x = 10   # variable defined in the enclosing scope

    class Inner:
        def foo(self):
            print(x)   # accesses the variable x defined in the enclosing scope

    Inner().foo()

outer()   # prints 10


def outer():
    x = 10   # variable defined in the enclosing scope

    def inner():
        nonlocal x
        x = 20   # modifies the value of the variable x defined in the enclosing scope

    inner()
    print(x)   # prints 20

outer()   # prints 20

x = 10   # global variable

def foo():
    global x
    x = 20   # changes the value of the global variable x
    print(x)   # prints 20

foo()   # prints 20
print(x)   # prints 20

def f(x,y):
    print('You called f(x,y) with the value x = ' + str(x) + ' and y = ' + str(y))
    print('x * y = ' + str(x*y))
    z = 4 # z is local here, and is not accessible outside the function

z = 3
f(3,2)

def f(x,y,z):
    return x+y+z # returns the sum as all variables are provided as arguments

result = f(3,2,1)
print(result)

def highFive():
    return 5

def f(x,y):
    z = highFive() # fetching value from the highFive function
    return x+y+z

result = f(3,2)
print(result)

def f(x,y):
    print('You called f(x,y) with the value x = ' + str(x) + ' and y = ' + str(y))
    print('x * y = ' + str(x*y))
    z = 4 # z is local here, and is not accessible outside the function

z = 3
f(3,2)

def f(x,y):
    z = 3
    print('You called f(x,y) with the value x = ' + str(x) + ' and y = ' + str(y))
    print('x * y = ' + str(x*y))
    print(z) # z is local and defined within the function

f(3,2)

def func1(a, b):
    a = 'new-value'        # a and b are local names
    b = b + 1              # assigned to new objects
    return a, b            # return new values

x, y = 'old-value', 99
func1(x, y)
# Out:
# Deposited 500. New balance: 1500
# Withdrew 300. New balance: 1200
# Insufficient funds.
# 10
# 5
# 200
# 100
# 20
# [1, 2, 3, 4]
# world
# 5
# 10
# 20
# 10
# 10
# 10
# 20
# 20
# 20
# You called f(x,y) with the value x = 3 and y = 2
# x * y = 6
# 6
# 10
# You called f(x,y) with the value x = 3 and y = 2
# x * y = 6
# You called f(x,y) with the value x = 3 and y = 2
# x * y = 6
# 3
# ('new-value', 100)

# %% [markdown]
# # **Parameters defined in Function Definition**
# We define parameter names in the function definition; it behaves like local variables. But they contain some values that we pass into the function to perform the desired action when we call it. Let’s take an example program based on it.
