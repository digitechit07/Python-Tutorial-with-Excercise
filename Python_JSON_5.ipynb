# %% [markdown]
# <a href="https://colab.research.google.com/github/digitechit07/Python-Tutorial-with-Excercise/blob/main/Python_JSON_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Dunder (Magic) Methods in JSONEncoder**
# These are the special methods for the JSONEncoder class in the json module that enable custom behavior for JSON serialization.
#
# Sr.No.	Method & Description
# 1	json.JSONEncoder.__init__
# Initializes the encoder with custom settings.
#
# 2	json.JSONEncoder.__repr__
# Returns a string representation of the encoder object.
#
# 3	json.JSONEncoder.__str__
# Returns a string version of the encoder object.

# %%
def validate_json_structure(data):
    required_keys = ['name', 'age', 'email']
    return all(key in data for key in required_keys)

def load_and_validate(filename):
    try:
        with open(filename, 'r') as file:
            data = json.load(file)
            if validate_json_structure(data):
                return data
            else:
                raise ValueError("Invalid JSON structure")
    except Exception as e:
        print(f"Validation failed: {e}")

import json
json_input = '{ "make": "Tesla", "model": "Model 3", "year": 2022, "color": "Red" }'
json_data = json.loads(json_input)
print(json_data) # Output: {'make': 'Tesla', 'model': 'Model 3', 'year': 2022, 'color': 'Red'}
import json
json_input = '{ "make": "Tesla", "model": "Model 3", "year": 2022, "color": "Red" }'
json_data = json.loads(json_input)
print(json_data) # Output: {'make': 'Tesla', 'model': 'Model 3', 'year': 2022, 'color': 'Red'}
import json

json_input = '{ "make": "Tesla", "model": "Model 3", "year": 2022, "color": "Red" }'
json_data = json.loads(json_input)
print(json_data) # Output: {'make': 'Tesla', 'model': 'Model 3', 'year': 2022, 'color': 'Red'}

import json
json_string ='{"numbers": [1, 2, 3], "car": {"model": "Model X", "year": 2022}}'
json_data = json.loads(json_string)
# Accessing JSON array elements using array indexing
print(json_data['numbers'][0]) # Output: 1
# Accessing JSON elements using keys
print(json_data['car']['model']) # Output: Model X
import json
json_string ='{"numbers": [1, 2, 3], "car": {"model": "Model X", "year": 2022}}'
json_data = json.loads(json_string) # Accessing JSON array elements using array indexing print(json_data['numbers'][0]) # Output: 1 # Accessing JSON elements using keys print(json_data['car']['model']) # Output: Model X
import json

json_string ='{"numbers": [1, 2, 3], "car": {"model": "Model X", "year": 2022}}'
json_data = json.loads(json_string)

# Accessing JSON array elements using array indexing
print(json_data['numbers'][0])  # Output: 1

# Accessing JSON elements using keys
print(json_data['car']['model'])  # Output: Model X

import json
json_string = '{"model": "Model X", "year": 2022}'
json_data = json.loads(json_string)
json_data['color'] = 'red'
print(json_data) # Output: {'model': 'Model X', 'year': 2022, 'color': 'red'}
import json
json_string = '{"model": "Model X", "year": 2022}'
json_data = json.loads(json_string)
json_data['color'] = 'red'
print(json_data) # Output: {'model': 'Model X', 'year': 2022, 'color': 'red'}
import json

json_string = '{"model": "Model X", "year": 2022}'
json_data = json.loads(json_string)
json_data['color'] = 'red'

print(json_data)  # Output: {'model': 'Model X', 'year': 2022, 'color': 'red'}

import json
json_string = '{"model": "Model X", "year": 2022}'
json_data = json.loads(json_string)
json_data['year'] = 2023
print(json_data) # Output: {'model': 'Model X', 'year': 2023}
import json
json_string = '{"model": "Model X", "year": 2022}'
json_data = json.loads(json_string)
json_data['year'] = 2023
print(json_data) # Output: {'model': 'Model X', 'year': 2023}
import json

json_string = '{"model": "Model X", "year": 2022}'
json_data = json.loads(json_string)
json_data['year'] = 2023

print(json_data)  # Output: {'model': 'Model X', 'year': 2023}

import json
json_string = '{"model": "Model X", "year": 2022}'
json_data = json.loads(json_string)
more_json_string = '{"model": "Model S", "color": "Red"}'
more_json_data = json.loads(more_json_string)
json_data.update(more_json_data)
print(json_data) # Output: {'model': 'Model S', 'year': 2022, 'color': 'Red'}
import json
json_string = '{"model": "Model X", "year": 2022}'
json_data = json.loads(json_string)
more_json_string = '{"model": "Model S", "color": "Red"}'
more_json_data = json.loads(more_json_string)
json_data.update(more_json_data)
print(json_data) # Output: {'model': 'Model S', 'year': 2022, 'color': 'Red'}
import json

json_string = '{"model": "Model X", "year": 2022}'
json_data = json.loads(json_string)

more_json_string = '{"model": "Model S", "color": "Red"}'
more_json_data = json.loads(more_json_string)

json_data.update(more_json_data)
print(json_data)  # Output: {'model': 'Model S', 'year': 2022, 'color': 'Red'}

import json
json_string = '{"model": "Model X", "year": 2022}'
json_data = json.loads(json_string)
del json_data['year']
import json
json_string = '{"model": "Model X", "year": 2022}'
json_data = json.loads(json_string)
#del json_data['year']
import json

json_string = '{"model": "Model X", "year": 2022}'
json_data = json.loads(json_string)
del json_data['year']

import json
json_string = '{"model": "Model X", "year": 2022}'
json_data = json.loads(json_string)
year = json_data.pop('year')
print(year) # Output: 2022
print(json_data) # Output: {'model': 'Model X'}
import json
json_string = '{"model": "Model X", "year": 2022}'
json_data = json.loads(json_string)
year = json_data.pop('year')
print(year) # Output: 2022 print(json_data) # Output: {'model': 'Model X'}
import json

json_string = '{"model": "Model X", "year": 2022}'
json_data = json.loads(json_string)
year = json_data.pop('year')

print(year)  # Output: 2022
print(json_data)  # Output: {'model': 'Model X'}

import json
json_string = '{"model": "Model X", "year": 2022}'
json_data = json.loads(json_string)
if 'year' in json_data:
  del json_data['year']
else:
  print('Key not found')
# or wrapping the del operation with a try/catch
json_string = '{"model": "Model X", "year": 2022}'
json_data = json.loads(json_string)
try:
  del json_data['year']
except KeyError:
  print('Key not found')

import json
json_string = '{"model": "Model X", "year": 2022}'
json_data = json.loads(json_string)
if 'year' in json_data:
  del json_data['year']
else:
  print('Key not found') # or wrapping the del operation with a try/catch json_string = '{"model": "Model X", "year": 2022}' json_data = json.loads(json_string) try: del json_data['year'] except KeyError: print('Key not found')

import json

json_string = '{"model": "Model X", "year": 2022}'
json_data = json.loads(json_string)
if 'year' in json_data:
    del json_data['year']
else:
    print('Key not found')

# or wrapping the del operation with a try/catch
json_string = '{"model": "Model X", "year": 2022}'
json_data = json.loads(json_string)
try:
    del json_data['year']
except KeyError:
    print('Key not found')
'''
import json
data = '{"model": "Model X", "year": 2022}'
# Saves the dictionary named data as a JSON object to the file data.json
with open("data.json", "w") as f:
json.dump(data, f)
import json data = '{"model": "Model X", "year": 2022}' # Saves the dictionary named data as a JSON object to the file data.json with open("data.json", "w") as f: json.dump(data, f)
import json

data = '{"model": "Model X", "year": 2022}'

# Saves the dictionary named data as a JSON object to the file data.json
with open("data.json", "w") as f:
    json.dump(data, f)
'''

import json
data = {"model": "Model X", "year": 2022}
# Converts the data dictionary to a JSON string representation
json_string = json.dumps(data)
print(json_string) # Output: {"model": "Model X", "year": 2022}

import json
data = {"model": "Model X", "year": 2022} # Converts the data dictionary to a JSON string representation json_string = json.dumps(data) print(json_string) # Output: {"model": "Model X", "year": 2022}
import json

data = {"model": "Model X", "year": 2022}

# Converts the data dictionary to a JSON string representation
json_string = json.dumps(data)

print(json_string)  # Output: {"model": "Model X", "year": 2022}
'''
import json
#import jmespath
json_string = '{"numbers": [1, 2, 3], "car": {"model": "Model X", "year": 2022}}'
json_data = json.loads(json_string)
# Accessing nested JSON
name = jmespath.search('car.model', json_data) # Result: Model X
# Taking the first number from numbers
first_number = jmespath.search('numbers[0]', json_data) # Result: 1
import json
#import jmespath
json_string = '{"numbers": [1, 2, 3], "car": {"model": "Model X", "year": 2022}}'
json_data = json.loads(json_string) # Accessing nested JSON name = jmespath.search('car.model', json_data) # Result: Model X # Taking the first number from numbers first_number = jmespath.search('numbers[0]', json_data) # Result: 1


import json
#import jmespath

json_string = '{"numbers": [1, 2, 3], "car": {"model": "Model X", "year": 2022}}'
json_data = json.loads(json_string)

# Accessing nested JSON
name = jmespath.search('car.model', json_data) # Result: Model X

# Taking the first number from numbers
first_number = jmespath.search('numbers[0]', json_data)  # Result: 1

#import jmespath
result = jmespath.search("""
[?price <= `25000`].{
Make: make,
Model: model,
Year: year
}
""",
cars)
#import jmespath
result = jmespath.search(""" [?price <= `25000`].{ Make: make, Model: model, Year: year } """, cars)

#import jmespath

result = jmespath.search("""
    [?price <= `25000`].{
        Make: make,
        Model: model,
        Year: year
    }
""", cars)
'''
# Out:
# {'make': 'Tesla', 'model': 'Model 3', 'year': 2022, 'color': 'Red'}
# {'make': 'Tesla', 'model': 'Model 3', 'year': 2022, 'color': 'Red'}
# {'make': 'Tesla', 'model': 'Model 3', 'year': 2022, 'color': 'Red'}
# 1
# Model X
# 1
# Model X
# {'model': 'Model X', 'year': 2022, 'color': 'red'}
# {'model': 'Model X', 'year': 2022, 'color': 'red'}
# {'model': 'Model X', 'year': 2022, 'color': 'red'}
# {'model': 'Model X', 'year': 2023}
# {'model': 'Model X', 'year': 2023}
# {'model': 'Model X', 'year': 2023}
# {'model': 'Model S', 'year': 2022, 'color': 'Red'}
# {'model': 'Model S', 'year': 2022, 'color': 'Red'}
# {'model': 'Model S', 'year': 2022, 'color': 'Red'}
# 2022
# {'model': 'Model X'}
# 2022
# 2022
# {'model': 'Model X'}
# {"model": "Model X", "year": 2022}
# {"model": "Model X", "year": 2022}
# '\nimport json\n#import jmespath\njson_string = \'{"numbers": [1, 2, 3], "car": {"model": "Model X", "year": 2022}}\'\njson_data = json.loads(json_string)\n# Accessing nested JSON\nname = jmespath.search(\'car.model\', json_data) # Result: Model X\n# Taking the first number from numbers\nfirst_number = jmespath.search(\'numbers[0]\', json_data) # Result: 1\nimport json \n#import jmespath \njson_string = \'{"numbers": [1, 2, 3], "car": {"model": "Model X", "year": 2022}}\' \njson_data = json.loads(json_string) # Accessing nested JSON name = jmespath.search(\'car.model\', json_data) # Result: Model X # Taking the first number from numbers first_number = jmespath.search(\'numbers[0]\', json_data) # Result: 1\n\n\nimport json\n#import jmespath\n\njson_string = \'{"numbers": [1, 2, 3], "car": {"model": "Model X", "year": 2022}}\'\njson_data = json.loads(json_string)\n\n# Accessing nested JSON\nname = jmespath.search(\'car.model\', json_data) # Result: Model X\n\n# Taking the first number from numbers\nfirst_number = jmespath.search(\'numbers[0]\', json_data)  # Result: 1\n\n#import jmespath\nresult = jmespath.search("""\n[?price <= `25000`].{\nMake: make,\nModel: model,\nYear: year\n}\n""", \ncars)\n#import jmespath \nresult = jmespath.search(""" [?price <= `25000`].{ Make: make, Model: model, Year: year } """, cars)\n\n#import jmespath\n\nresult = jmespath.search("""\n    [?price <= `25000`].{\n        Make: make,\n        Model: model,\n        Year: year\n    }\n""", cars)\n'

# %% [markdown]
# # **Dunder (Magic) Methods in JSONDecoder**
# These are the special methods for the JSONDecoder class that enable custom behavior for JSON deserialization.
#
# Sr.No.	Method & Description
# 1	json.JSONDecoder.__init__
# Initializes the decoder with custom settings.
#
# 2	json.JSONDecoder.__repr__
# Returns a string representation of the decoder object.
#
# 3	json.JSONDecoder.__str__
# Returns a string version of the decoder object.

# %%
import json

# JSON string
smartphone_json = '{"name": "iPear 23", "colors": ["black", "white", "red", "blue"], "price": 999.99, "inStock": true}'
# from JSON string to Python dict
smartphone_dict = json.loads(smartphone_json)

# verify the type of the resulting variable
print(type(smartphone_dict)) # dict


import json

json_string = '15.5'
float_var = json.loads(json_string)

print(type(float_var)) # <class 'float'>
import json

user_dict = {
    "name": "John",
    "surname": "Williams",
    "age": 48,
    "city": "New York"
}

user_json_string = json.dumps(user_dict)

print(user_json_string)


import json

json_string = '[{"id": 2, "name": "Basilisk"}, {"id": 6, "name": "Nagaraja"}]'
data = json.loads(json_string)

print(data[0])  # {'id': 2, 'name': 'Basilisk'}
print(data[1]["name"]) # Nagaraja


# Four Fundamental Forces with JSON
d = {}

d ["gravity"] = {
"mediator":"gravitons",
"relative strength" : "1",
"range" : "infinity"
}
d ["weak"] = {
"mediator":"W/Z bosons",
"relative strength" : "10^25",
"range" : "10^-18"
}
d ["electromagnetic"] = {
"mediator":"photons",
"relative strength" : "10^36",
"range" : "infinity"
}
d ["strong"] = {
"mediator":"gluons",
"relative strength" : "10^38",
"range" : "10^-15"
}

print(d)

import json
data = json.dumps(d)
print(type(data))
print(data)


# Four Fundamental Forces with JSON
d = {}

d ["gravity"] = {
"mediator":"gravitons",
"relative strength" : "1",
"range" : "infinity"
}
d ["weak"] = {
"mediator":"W/Z bosons",
"relative strength" : "10^25",
"range" : "10^-18"
}
d ["electromagnetic"] = {
"mediator":"photons",
"relative strength" : "10^36",
"range" : "infinity"
}
d ["strong"] = {
"mediator":"gluons",
"relative strength" : "10^38",
"range" : "10^-15"
}

import json

# encoding to JSON
data = json.dumps(d)

import json
json_string = '{"name": "John", "age": 30}'
data = json.loads(json_string)
print(data)

# Output:
# {'name': 'John', 'age': 30}

import json

# a JSON formatted string
json_string = '{"fruit": "Apple", "size": "Large", "color": "Red"}'

# using json.loads to decode the JSON data
python_obj = json.loads(json_string)

print(python_obj)

# Output:
# {'fruit': 'Apple', 'size': 'Large', 'color': 'Red'}


import json

# a JSON formatted string with nested data
json_string = '{"person": {"name": "John", "age": 30, "city": "New York"}}'

# using json.loads to decode the JSON data
python_obj = json.loads(json_string)

print(python_obj)

# Output:
# {'person': {'name': 'John', 'age': 30, 'city': 'New York'}}


import json
'''
# assuming 'data.json' contains: {"name": "John", "age": 30}
with open('data.json', 'r') as file:
    data = json.load(file)
    print(data)

# Output:
# {'name': 'John', 'age': 30}


import json

# a malformed JSON string
json_string = '{"name" "John", "age": 30}'

try:
    data = json.loads(json_string)
except json.decoder.JSONDecodeError as e:
    print(f'Error decoding JSON: {e}')

# Output:
# Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 8 (char 7)


import json

# a malformed JSON string
json_string = {"name": "John", "age": 30'}

try:
    data = json.loads(json_string)
except json.decoder.JSONDecodeError as e:
    print(f'Error decoding JSON: {e}')

# Output:
# Error decoding JSON: Expecting property name enclosed in double quotes: line 1 column 29 (char 28)


import json
import requests

# Make a request
response = requests.get('https://api.example.com/data')

# Use json.loads to parse the response
data = json.loads(response.text)

print(data)
'''
# Output:
# {'data': [{'id': 1, 'name': 'John'}, {'id': 2, 'name': 'Jane'}]}

import json

# a JSON formatted string
json_string = '[{"name": "John", "age": 30}, {"name": "Jane", "age": 25}]'

# using json.loads to decode the JSON data
data = json.loads(json_string)

# calculate the average age
average_age = sum(person['age'] for person in data) / len(data)
print(average_age)

# Output:
# 27.5
# Out:
# <class 'dict'>
# <class 'float'>
# {"name": "John", "surname": "Williams", "age": 48, "city": "New York"}
# {'id': 2, 'name': 'Basilisk'}
# Nagaraja
# {'gravity': {'mediator': 'gravitons', 'relative strength': '1', 'range': 'infinity'}, 'weak': {'mediator': 'W/Z bosons', 'relative strength': '10^25', 'range': '10^-18'}, 'electromagnetic': {'mediator': 'photons', 'relative strength': '10^36', 'range': 'infinity'}, 'strong': {'mediator': 'gluons', 'relative strength': '10^38', 'range': '10^-15'}}
# <class 'str'>
# {"gravity": {"mediator": "gravitons", "relative strength": "1", "range": "infinity"}, "weak": {"mediator": "W/Z bosons", "relative strength": "10^25", "range": "10^-18"}, "electromagnetic": {"mediator": "photons", "relative strength": "10^36", "range": "infinity"}, "strong": {"mediator": "gluons", "relative strength": "10^38", "range": "10^-15"}}
# {'name': 'John', 'age': 30}
# {'fruit': 'Apple', 'size': 'Large', 'color': 'Red'}
# {'person': {'name': 'John', 'age': 30, 'city': 'New York'}}
# 27.5

# %% [markdown]
# # **Functions in json.encoder (Internal Utility Functions)**
# These functions are used internally in the json.encoder module to handle specific encoding tasks.
#
# Sr.No.	Function & Description
# 1	json.encoder.encode_basestring()
# Encodes a string into a JSON-compatible format.
#
# 2	json.encoder.encode_basestring_ascii()
# Encodes a string into a JSON-compatible ASCII format.

# %%
import json

# Sample JSON content in 'data.json':
# {
#     "name": "Alice",
#     "age": 30,
#     "is_student": false,
#     "courses": ["Math", "Science", "Art"]
# }
'''
# Open the JSON file
with open('data.json', 'r') as file:
    # Load JSON data into a Python object
    data = json.load(file)

# Print the Python object
print(data)  # Output: {'name': 'Alice', 'age': 30, 'is_student': False, 'courses': ['Math', 'Science', 'Art']}
'''
import json

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

def decode_person(dct):
    if "name" in dct and "age" in dct:
        return Person(dct["name"], dct["age"])
    return dct
'''
with open('data.json', 'r') as file:
    person = json.load(file, object_hook=decode_person)

print(person.__dict__)
'''
json_string = '''
{
    "username": "john_doe",
    "active": true,
    "email": "john.doe@example.com",
    "roles": ["admin", "user"],
    "age": 28
}
'''


import json

# Parsing JSON string
user_profile = json.loads(json_string)


print(user_profile["username"])  # Output: john_doe
print(user_profile["active"])    # Output: True
print(user_profile["email"])     # Output: john.doe@example.com
print(user_profile["roles"])     # Output: ['admin', 'user']
print(user_profile["age"])       # Output: 28


class Book:
    def __init__(self, title, author, year, genres):
        self.title = title
        self.author = author
        self.year = year
        self.genres = genres

class BookEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, Book):
            return obj.__dict__
        return super().default(obj)

book = Book("To Kill a Mockingbird", "Harper Lee", 1960, ["Fiction", "Drama"])
json_string = json.dumps(book, cls=BookEncoder)
print(json_string)


import json

class PersonEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, Person):
            return obj.__dict__
        return super().default(obj)

person = Person("Alice", 30)
json_string = json.dumps(person, cls=PersonEncoder)
print(json_string)  # Output: {"name": "Alice", "age": 30}

class BookEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, Book):
            return {
                "title": obj.title,
                "author": obj.author,
                "published_year": obj.published_year,
                "genres": obj.genres
            }
        return super().default(obj)


book = Book("To Kill a Mockingbird", "Harper Lee", 1960, ["Fiction", "Drama"])
#json_string = json.dumps(book, cls=BookEncoder, indent=4)
#print(json_string)

class Publisher:
    def __init__(self, name, founded):
        self.name = name
        self.founded = founded

class Book:
    def __init__(self, title, author, published_year, genres, publisher):
        self.title = title
        self.author = author
        self.published_year = published_year
        self.genres = genres
        self.publisher = publisher

class ComplexEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, Book):
            return {
                "title": obj.title,
                "author": obj.author,
                "published_year": obj.published_year,
                "genres": obj.genres,
                "publisher": obj.publisher.__dict__
            }
        if isinstance(obj, Publisher):
            return obj.__dict__
        return super().default(obj)

publisher = Publisher("J.B. Lippincott & Co.", 1836)
book = Book("To Kill a Mockingbird", "Harper Lee", 1960, ["Fiction", "Drama"], publisher)
#json_string = json.dumps(book, cls=ComplexEncoder, indent=4)
#print(json_string)

import json

json_string = '{"name": "Alice", "age": 30}'
person = json.loads(json_string, object_hook=decode_person)
print(person.name)  # Output: Alice
print(person.age)   # Output: 30

json_string = '''
{
    "title": "To Kill a Mockingbird",
    "author": "Harper Lee",
    "published_year": 1960,
    "genres": ["Fiction", "Drama"]
}

book = json.loads(json_string, object_hook=decode_book)
print(book.title)          # Output: To Kill a Mockingbird
print(book.author)         # Output: Harper Lee
print(book.published_year) # Output: 1960
print(book.genres)         # Output: ['Fiction', 'Drama']
'''
class Publisher:
    def __init__(self, name, founded):
        self.name = name
        self.founded = founded

class Book:
    def __init__(self, title, author, published_year, genres, publisher):
        self.title = title
        self.author = author
        self.published_year = published_year
        self.genres = genres
        self.publisher = publisher

def decode_complex(dct):
    if "name" in dct and "founded" in dct:
        return Publisher(dct["name"], dct["founded"])
    if "title" in dct and "author" in dct and "published_year" in dct and "genres" in dct :
        publisher = decode_complex(dct["publisher"])
        return Book(dct["title"], dct["author"], dct["published_year"], dct["genres"], publisher)
    return dct

json_string = '''
{
    "title": "To Kill a Mockingbird",
    "author": "Harper Lee",
    "published_year": 1960,
    "genres": ["Fiction", "Drama"],
    "publisher": {
        "name": "J.B. Lippincott & Co.",
        "founded": 1836
    }
}
'''
#book = json.loads(json_string, object_hook=decode_complex)
#print(book.title)             # Output: To Kill a Mockingbird
#print(book.publisher.name)    # Output: J.B. Lippinc
# Out:
# john_doe
# True
# john.doe@example.com
# ['admin', 'user']
# 28
# {"title": "To Kill a Mockingbird", "author": "Harper Lee", "year": 1960, "genres": ["Fiction", "Drama"]}
# {"name": "Alice", "age": 30}
# Alice
# 30

# %% [markdown]
# # **Functions in json.decoder (Internal Utility Functions)**
# These functions are used internally in the json.decoder module to handle specific decoding tasks.
#
# Sr.No.	Function & Description
# 1	json.decoder.scanstring()
# Scans a string in JSON format.
#
# 2	json.decoder.JSONArray()
# Handles JSON array decoding.
