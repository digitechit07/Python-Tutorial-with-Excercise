# %% [markdown]
# <a href="https://colab.research.google.com/github/digitechit07/Python-Tutorial-with-Excercise/blob/main/Python_Dictionaries_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Python dict() Function**
#
#
# dict() function in Python is a built-in constructor used to create dictionaries. A dictionary is a mutable, unordered collection of key-value pairs, where each key is unique. The dict() function provides a flexible way to initialize dictionaries from various data structures.

# %%
all_examples = ['A,1,1', 'B,2,1', 'C,4,4', 'D,4,5']

map(dict, zip(*[[(s[0], int(x)) for x in s.split(',')[1:]] for s in all_examples]))

all_examples = ['A,1,1', 'B,2,1', 'C,4,4', 'D,4,5']
ll = [ x.split(",") for x in all_examples ]
ld = list()
for col in range(1, len(ll[0])):
    ld.append({ l[0] : int(l[col]) for l in ll })
print(ld)

d=dict(One = "1", Two = "2")
print(d)

# passing keyword arguments
d = dict(a=1, b=2, c=3, d=4)

print(d)

d= {'a': 1, 'b': 2, 'c': 3}

# deep copy using dict
d_deep = dict(d)

# shallow copy without dict
d_shallow = d

# changing value in shallow copy will change d
d_shallow['a'] = 10
print(d)

# changing value in deep copy won't affect d
d_deep['b'] = 20
print(d)

# creating a dictionary from a list of tuples
d = dict([('a', 1), ('b', 2), ('c', 3)], d=4)

print(d)

my_dict = {'name': 'Alice', 'age': 30, 'city': 'New York'}
items = my_dict.items()
print(items)  # Output: dict_items([('name', 'Alice'), ('age', 30), ('city', 'New York')])

original_dict = {'name': 'Alice', 'age': 30}
copied_dict = dict(original_dict)
print(copied_dict)  # Output: {'name': 'Alice', 'age': 30}

my_dict = {'name': 'Alice', 'age': 30, 'city': 'New York'}
keys = my_dict.keys()
print(type(keys))  # Output: <class 'dict_keys'>
print(keys)  # Output: dict_keys(['name', 'age', 'city'])

my_dict = {
    "name": "David",
    "age": 28,
    "city": "Houston"
}

# Access values using keys
name = my_dict["name"]
age = my_dict["age"]
city = my_dict["city"]

print(name)  # Output: David
print(age)   # Output: 28
print(city)  # Output: Houston

my_dict = {
    "name": "Eve",
    "age": 35
}

# Add a new key-value pair
my_dict["city"] = "Miami"

print(my_dict)
# Output: {'name': 'Eve', 'age': 35, 'city': 'Miami'}

my_dict = {
    "name": "Frank",
    "age": 40,
    "city": "Phoenix"
}

# Update the value of the 'age' key
my_dict["age"] = 45

print(my_dict)
# Output: {'name': 'Frank', 'age': 45, 'city': 'Phoenix'}

my_dict = {
    "name": "Grace",
    "age": 50,
    "city": "Seattle"
}

# Remove the 'city' key-value pair
del my_dict["city"]

print(my_dict)
# Output: {'name': 'Grace', 'age': 50}

my_dict = {
    "name": "Hannah",
    "age": 22
}

age = my_dict.get("age")
city = my_dict.get("city")

print(age)  # Output: 22
print(city)  # Output: None

my_dict = {
    "name": "Isaac",
    "age": 30,
    "city": "San Francisco"
}

keys = my_dict.keys()

print(keys)  # Output: dict_keys(['name', 'age', 'city'])

my_dict = {
    "name": "Jane",
    "age": 25,
    "city": "Dallas"
}

values = my_dict.values()

print(values)  # Output: dict_values(['Jane', 25, 'Dallas'])

my_dict = {
    "name": "Kevin",
    "age": 35,
    "city": "Boston"
}

items = my_dict.items()

print(items)  # Output: dict_items([('name', 'Kevin'), ('age', 35), ('city', 'Boston')])

# dictionary
numbers = {1: "one", 2: "two"}

# removes all the items from the dictionary
numbers.clear()

print(numbers)

# Output: {}

original_marks = {'Physics':67, 'Maths':87}

copied_marks = original_marks.copy()


print('Original Marks:', original_marks)
print('Copied Marks:', copied_marks)

# Output: Original Marks: {'Physics': 67, 'Maths': 87}
#         Copied Marks: {'Physics': 67, 'Maths': 87}

# keys for the dictionary
alphabets = {'a', 'b', 'c'}

# value for the dictionary
number = 1

# creates a dictionary with keys and values
dictionary = dict.fromkeys(alphabets, number)

print(dictionary)

# Output: {'a': 1, 'c': 1, 'b': 1}

scores = {
    'Physics': 67,
    'Maths': 87,
    'History': 75
}

result = scores.get('Physics')

print(result)    # 67

marks = {'Physics':67, 'Maths':87}

print(marks.items())


# Output: dict_items([('Physics', 67), ('Maths', 87)])

numbers = {1: 'one', 2: 'two', 3: 'three'}

# extracts the keys of the dictionary
dictionaryKeys = numbers.keys()

print(dictionaryKeys)

# Output: dict_keys([1, 2, 3])
# Out:
# [{'A': 1, 'B': 2, 'C': 4, 'D': 4}, {'A': 1, 'B': 1, 'C': 4, 'D': 5}]
# {'One': '1', 'Two': '2'}
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}
# {'a': 10, 'b': 2, 'c': 3}
# {'a': 10, 'b': 2, 'c': 3}
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}
# dict_items([('name', 'Alice'), ('age', 30), ('city', 'New York')])
# {'name': 'Alice', 'age': 30}
# <class 'dict_keys'>
# dict_keys(['name', 'age', 'city'])
# David
# 28
# Houston
# {'name': 'Eve', 'age': 35, 'city': 'Miami'}
# {'name': 'Frank', 'age': 45, 'city': 'Phoenix'}
# {'name': 'Grace', 'age': 50}
# 22
# None
# dict_keys(['name', 'age', 'city'])
# dict_values(['Jane', 25, 'Dallas'])
# dict_items([('name', 'Kevin'), ('age', 35), ('city', 'Boston')])
# {}
# Original Marks: {'Physics': 67, 'Maths': 87}
# Copied Marks: {'Physics': 67, 'Maths': 87}
# {'b': 1, 'a': 1, 'c': 1}
# 67
# dict_items([('Physics', 67), ('Maths', 87)])
# dict_keys([1, 2, 3])

# %% [markdown]
# # **Syntax of dict()**
# dict(iterable)
#
# dict(mapping)
#
# dict(**kwargs)
#
# dict(iterable, **kwargs)
#
# dict(mapping, **kwargs)
#
# Parameter:
#
# iterable (optional): An iterable such as a list of tuples where each tuple contains a key-value pair.
# mapping (optional): An existing dictionary or mapping object that will be used to create a new dictionary.
# kwargs (optional): Keyword arguments where keys are strings, used to pass key-value pairs directly.
# Return: The function returns a dictionary containing the specified key-value pairs.

# %%
# create a dictionary
marks = { 'Physics': 67, 'Chemistry': 72, 'Math': 89 }

element = marks.pop('Chemistry')

print('Popped Marks:', element)

# Output: Popped Marks: 72

marks = {'Physics':67, 'Maths':87}

print(marks.values())


# Output: dict_values([67, 87])

marks = {'Physics':67, 'Maths':87}
internal_marks = {'Practical':48}

marks.update(internal_marks)


print(marks)

# Output: {'Physics': 67, 'Maths': 87, 'Practical': 48}

d = {'x': 1, 'y': 2, 'z': 10}
print(d) # {'x': 1, 'y': 2, 'z': 10}

# remove everything
d.clear()

print(d) # {}

d = {'x': 1, 'y': 2, 'z': 10}

print(d.get('a') == None) # True

d = {'x': 1, 'y': 2, 'z': 10}

print(d.get('a', 0)) # 0

d = {'x': 1, 'y': 2, 'z': 10}

key = 'x'
value = d.pop(key)

print('Deleted the item:', key + ':', value)
print('Dictionary d now:', d)

d = {'x': 1, 'y': 2, 'z': 10}

print('Removed:', d.popitem())
print('Dictionary d now:', d)

d1 = {'x': 1, 'y': 2, 'z': 10}
d2 = d1

# make a change in d1
d1['x'] = 500

print(d1['x']) # 500

# the change would be visible in d2 as well
print(d2['x']) # 500

d1 = {'x': 1, 'y': 2, 'z': 10}
d2 = d1.copy()

# make a change in d1
d1['x'] = 500

print(d1['x']) # 500

# the change would not be visible in d2
print(d2['x']) # 1

d = {'a': 1, 'b': 2}
d.clear()  # {}

d = {'a': 1, 'b': 2}
new_d = d.copy()  # {'a': 1, 'b': 2}

keys = ['a', 'b', 'c']
d = dict.fromkeys(keys, 0)  # {'a': 0, 'b': 0, 'c': 0}

d = {'a': 1, 'b': 2}
d.get('a')  # 1
d.get('c', 0)  # 0

d = {'a': 1, 'b': 2}
d.items()  # dict_items([('a', 1), ('b', 2)])

d = {'a': 1, 'b': 2}
d.keys()  # dict_keys(['a', 'b'])

d = {'a': 1, 'b': 2}
d.pop('a')  # 1, d = {'b': 2}
d.pop('c', 0)  # 0

d = {'a': 1, 'b': 2}
d.popitem()  # ('b', 2)

d = {'a': 1}
d.setdefault('b', 2)  # 2, d = {'a': 1, 'b': 2}


d = {'a': 1, 'b': 2}
d.update({'b': 3, 'c': 4})  # {'a': 1, 'b': 3, 'c': 4}

d = {'a': 1, 'b': 2}
d.values()  # dict_values([1, 2])

d = {'a': 1, 'b': 2}
len(d)  # 2

d = {'a': 1, 'b': 2}
'a' in d  # True
'c' in d  # False

d = {'a': 1, 'b': 2}
del d['a']  # d = {'b': 2}


device ={
  "vendor": "Cisco",
  "model": "9000 series",
  "RU": 44
}
x = device.get("vendor")
print(x)

device ={
  "vendor": "Cisco",
  "model": "9000 series",
  "RU": 44
  }
x = device.get("port speed", 400)
print(x)

device ={
  "vendor": "Cisco",
  "model": "9000 series",
  "RU": 44
}
x = device.keys()
print(x)

device ={
  "vendor": "Cisco",
  "model": "9000 series",
  "RU": 44
}
x = device.keys()
device["port speed"] = "400G"
print(x)

device ={
  "vendor": "Cisco",
  "model": "9000 series",
  "RU": 44
}
x = device.values()
print(x)

device ={
  "vendor": "Cisco",
  "model": "9000 series",
  "RU": 44
}
x = device.values()
device["port speed"] = "400G"
print(x)

device ={
  "vendor": "Cisco",
  "model": "9000 series",
  "RU": 44
}
x = device.items()
print(x)

device ={
  "vendor": "Cisco",
  "model": "9000 series",
  "RU": 44
}
device.pop("model")
print(device)

device ={
  "vendor": "Cisco",
  "model": "9000 series",
  "RU": 44
}
x = device.pop("model")
print(x)

device ={
  "vendor": "Nokia",
  "model": "7950 XRS",
  "RU": 39
}
device.popitem()
print(device)

device ={
  "vendor": "Nokia",
  "model": "7950 XRS",
  "RU": 39
}
x=device.popitem()
print(x)

device ={
  "vendor": "Cisco",
  "model": "9000 series",
  "RU": 44
}
x = device.setdefault("model","5000 series")
print(x)

device ={
  "vendor": "Cisco",
  "model": "9000 series",
  "RU": 44
}
x = device.setdefault("RU","50")
print(x)

device ={
  "vendor": "Nokia",
  "model": "7950 XRS",
  "RU": 39
}
device.update({"speed": "400G"})
print(device)

device ={
  "vendor": "Cisco",
  "model": "9000 series",
  "RU": 44
  }
device.clear()
print(device)

device ={
  "vendor": "Cisco",
  "model": "9000 series",
  "RU": 44
  }
x=device.copy()
print(x)

vendors = ('Cisco', 'Nokia', 'Huawei')
x = dict.fromkeys(vendors)
print(x)

devices = ('Routers', 'Switches', 'Firewalls')
vendors = ('Cisco', 'Nokia', 'Huawei')
x = dict.fromkeys(devices,vendors)
print(x)
# Out:
# Popped Marks: 72
# dict_values([67, 87])
# {'Physics': 67, 'Maths': 87, 'Practical': 48}
# {'x': 1, 'y': 2, 'z': 10}
# {}
# True
# 0
# Deleted the item: x: 1
# Dictionary d now: {'y': 2, 'z': 10}
# Removed: ('z', 10)
# Dictionary d now: {'x': 1, 'y': 2}
# 500
# 500
# 500
# 1
# Cisco
# 400
# dict_keys(['vendor', 'model', 'RU'])
# dict_keys(['vendor', 'model', 'RU', 'port speed'])
# dict_values(['Cisco', '9000 series', 44])
# dict_values(['Cisco', '9000 series', 44, '400G'])
# dict_items([('vendor', 'Cisco'), ('model', '9000 series'), ('RU', 44)])
# {'vendor': 'Cisco', 'RU': 44}
# 9000 series
# {'vendor': 'Nokia', 'model': '7950 XRS'}
# ('RU', 39)
# 9000 series
# 44
# {'vendor': 'Nokia', 'model': '7950 XRS', 'RU': 39, 'speed': '400G'}
# {}
# {'vendor': 'Cisco', 'model': '9000 series', 'RU': 44}
# {'Cisco': None, 'Nokia': None, 'Huawei': None}
# {'Routers': ('Cisco', 'Nokia', 'Huawei'), 'Switches': ('Cisco', 'Nokia', 'Huawei'), 'Firewalls': ('Cisco', 'Nokia', 'Huawei')}

# %% [markdown]
# # **Some Uses of Python Dictionary**
#
# Data Retrieval: Dictionaries are excellent for quick data retrieval when you have a unique identifier (the key). For example, you can use a dictionary to store and access information about individuals using their names as keys.
# Counting and Frequency: Dictionaries are useful for counting occurrences of items in a dataset. You can use items as keys and increment their corresponding values to keep track of frequencies, making them handy for tasks like word frequency analysis.
# Configuration Settings: Dictionaries can store configuration settings for applications. Keys can represent setting names, and values can store the configuration options. This makes it easy to change and retrieve settings as needed.
# Caching: Dictionaries can be used as a cache to store expensive or frequently used results of function calls, database queries, or other computations. This can improve the performance of your programs.
# Mapping: Dictionaries are often used to create mappings between two sets of data. For example, you can map employee IDs to employee names or postal codes to city names.
# Graphs and Trees: Dictionaries can represent graph or tree structures by using keys as nodes and values as edges or child nodes, allowing for the efficient traversal of these structures.
# Lookup Tables: Dictionaries can serve as lookup tables, where keys represent codes or identifiers, and values provide corresponding information, like translating country codes to country names.

# %%
coder = {
    "name": "Alex",
    "language": "Python",
    "experience": 3,
    "skills": ["Django", "Flask", "APIs"]
}

print(coder["language"])
print(coder["skills"][1])


address = {
    "name": "Wscubetech",
    "location1": "Jodhpur",
    "location2": "Jaipur"
}
print(address)

address = {
    "name": "WsCubeTech",
    "location1": "Jodhpur"
}

# Adding a new key-value pair
address["location2"] = "Jaipur"

print(address)

address = {
    "name": "WsCubeTech",
    "location1": "Jodhpur",
    "location2": "Jaipur"
}

print(address["name"])       # Using square brackets
print(address.get("location1"))  # Using get() method

data = {"name": "WsCube", "city": "Jaipur", "course": "Python"}

del data["city"]              # Remove 'city'
print(data.pop("course"))     # Remove and return 'course'
data.popitem()                # Remove last item ('name')
data.clear()                  # Remove everything
print(data)

info = {"name": "WsCube", "course": "Python"}

for key, value in info.items():
    print(key, ":", value)

    coders = {
    "coder1": {"name": "Alex", "language": "Python", "experience": 3},
    "coder2": {"name": "Max", "language": "JavaScript", "experience": 5}
}

print(coders["coder1"]["name"])
print(coders["coder2"]["language"])

data = {"name": "Alex", "language": "Python", "experience": 3}

# Get value of a key
print(data.get("language"))

# Remove an element
data.pop("experience")
print(data)

# Add default key if missing
data.setdefault("location", "Unknown")
print(data)

# Copy dictionary
data_copy = data.copy()
print(data_copy)

details = {"name": "John", "age": 34, "place": "London"}
list = details.items()
print(list)

details = {"name": "John", "age": 34, "place": "London"}
list = details.values()
print(list)
details = {"name": "John", "age": 34, "place": "London"}
list = details.get('place')
print(list)

details = {"name": "John", "age": 34, "place": "London"}
list = details.pop('place')
print(list)

details = {"name": "John", "age": 34, "place": "London"}
list = details.popitem()
print(details)

details = {"name": "John", "age": 34, "place": "London"}
details.update({"height":178})
print(details)

lst = [3, "age"]
print(dict.fromkeys(lst,20))

details = {"name": "John", "age": 34, "place": "London"}
details1 = details.copy()
print(details1)

details = {"name": "John", "age": 34, "place": "London"}
details.clear()
print(details)

# create dictionary
my_dict = dict(Names = ["Amaka", "Chad", "Kemi", "Jack", "Tim"],
               Age = [22, 24, 30, 27, 32])
print(my_dict)

# {'Names': ['Amaka', 'Chad', 'Kemi', 'Jack', 'Tim'], 'Age': [22, 24, 30, 27, 32]}

# update dicitonary with another dictionary
another_dict = {"Count":[1,2,3,4,5]}

my_dict.update(another_dict)

print(my_dict)

# {'Names': ['Amaka', 'Chad', 'Kemi', 'Jack', 'Tim'], 'Age': [22, 24, 30, 27, 32], 'Count': [1, 2, 3, 4, 5]}

# remove an item with a specified key and return its values
values = my_dict.pop("Age")

print(values)

print(my_dict)

# [22, 24, 30, 27, 32]

# {'Names': ['Amaka', 'Chad', 'Kemi', 'Jack', 'Tim']}

# remove the last item in a dictionary and return its key-value pair as a tuple.
tup = my_dict.popitem()

print(tup)

print(my_dict)

# ('Age': [22, 24, 30, 27, 32])

# {'Names': ['Amaka', 'Chad', 'Kemi', 'Jack', 'Tim']}

# create nested list
nested_list = [["Amaka", "Chad", "Kemi", "Jack", "Tim"],[22, 24, 30, 27, 32]]

print(nested_list)

# [['Amaka', 'Chad', 'Kemi', 'Jack', 'Tim'], [22, 24, 30, 27, 32]]

new_dict = dict()

for i in nested_list[0]:

  for j in nested_list[1]:

    new_dict.setdefault(i,j)

print(new_dict)

# {'Amaka': 22, 'Chad': 22, 'Kemi': 22, 'Jack': 22, 'Tim': 22}

# Delete all key: value pairs from the dictionary
technology = { 'course':'python', 'fee': 4000, 'duration': '60 days' }
technology.clear()
print("Technology:", technology)

# Returns empty dictionary
# Technology: {}

# Using copy() method copy the technology dictionary
technology = { 'course':'python', 'fee': 4000, 'duration': '60 days' }
new_technology=technology.copy()
print("Original technology: ",technology)
print("New technology: ",new_technology)

# Output:
# Original technology:  {'course': 'python', 'fee': 4000, 'duration': '60 days'}
# New technology:  {'course': 'python', 'fee': 40000, 'duration': '60 days'}

# Create a dictionary using fromkeys()
technology ={"course","fee","duration"}
dictionary=dict.fromkeys(technology ,'language')
print(dictionary)

# Output:
# {'fee': 'language', 'course': 'language', 'duration': 'language'}

# Using get() method to get the value from dictionary
technology={'course': 'python', 'fee': 4000}

print('course:', technology.get('course'))
# course: python

print('fee:',technology.get('fee'))
# fee: 4000

# Using the items() to get dictionary elements
technology = { 'course':'python', 'fee': 4000, 'duration': '60 days' }
print(technology.items())

# Output:
# dict_items([('course', 'python'), ('fee', 4000), ('duration', '60 days')])

# Update the keys() method if update the dictionary
technology={"Course":"python","Fee":4000,"Duration":"60 days"}
print(technology.keys())

# Output:
# dict_keys(['Course', 'Fee', 'Duration'])

technology.update({"tutor": "Richard"})
print(technology.keys())

# Output:
# dict_keys(['Course', 'Fee', 'Duration', 'tutor'])
# Out:
# Python
# Flask
# {'name': 'Wscubetech', 'location1': 'Jodhpur', 'location2': 'Jaipur'}
# {'name': 'WsCubeTech', 'location1': 'Jodhpur', 'location2': 'Jaipur'}
# WsCubeTech
# Jodhpur
# Python
# {}
# name : WsCube
# course : Python
# Alex
# JavaScript
# Python
# {'name': 'Alex', 'language': 'Python'}
# {'name': 'Alex', 'language': 'Python', 'location': 'Unknown'}
# {'name': 'Alex', 'language': 'Python', 'location': 'Unknown'}
# dict_items([('name', 'John'), ('age', 34), ('place', 'London')])
# dict_values(['John', 34, 'London'])
# London
# London
# {'name': 'John', 'age': 34}
# {'name': 'John', 'age': 34, 'place': 'London', 'height': 178}
# {3: 20, 'age': 20}
# {'name': 'John', 'age': 34, 'place': 'London'}
# {}
# {'Names': ['Amaka', 'Chad', 'Kemi', 'Jack', 'Tim'], 'Age': [22, 24, 30, 27, 32]}
# {'Names': ['Amaka', 'Chad', 'Kemi', 'Jack', 'Tim'], 'Age': [22, 24, 30, 27, 32], 'Count': [1, 2, 3, 4, 5]}
# [22, 24, 30, 27, 32]
# {'Names': ['Amaka', 'Chad', 'Kemi', 'Jack', 'Tim'], 'Count': [1, 2, 3, 4, 5]}
# ('Count', [1, 2, 3, 4, 5])
# {'Names': ['Amaka', 'Chad', 'Kemi', 'Jack', 'Tim']}
# [['Amaka', 'Chad', 'Kemi', 'Jack', 'Tim'], [22, 24, 30, 27, 32]]
# {'Amaka': 22, 'Chad': 22, 'Kemi': 22, 'Jack': 22, 'Tim': 22}
# Technology: {}
# Original technology:  {'course': 'python', 'fee': 4000, 'duration': '60 days'}
# New technology:  {'course': 'python', 'fee': 4000, 'duration': '60 days'}
# {'fee': 'language', 'course': 'language', 'duration': 'language'}
# course: python
# fee: 4000
# dict_items([('course', 'python'), ('fee', 4000), ('duration', '60 days')])
# dict_keys(['Course', 'Fee', 'Duration'])
# dict_keys(['Course', 'Fee', 'Duration', 'tutor'])

# %% [markdown]
# # **Dictionary Methods**
# Sr.No.	Method and Description
# 1
# dict.clear()
#
# Removes all elements of dictionary dict.
#
# 2
# dict.copy()
#
# Returns a shallow copy of dictionary dict.
#
# 3
# dict.fromkeys()
#
# Create a new dictionary with keys from seq and values set to value.
#
# 4
# dict.get(key, default=None)
#
# For key key, returns value or default if key not in dictionary.
#
# 5
# dict.has_key(key)
#
# Returns true if a given key is available in the dictionary, otherwise it returns a false.
#
# 6
# dict.items()
#
# Returns a list of dict's (key, value) tuple pairs.
#
# 7
# dict.keys()
#
# Returns list of dictionary dict's keys.
#
# 8
# dict.pop()
#
# Removes the element with specified key from the collection
#
# 9
# dict.popitem()
#
# Removes the last inserted key-value pair
#
# 10
# dict.setdefault(key, default=None)
#
# Similar to get(), but will set dict[key]=default if key is not already in dict.
#
# 11
# dict.update(dict2)
#
# Adds dictionary dict2's key-values pairs to dict.
#
# 12
# dict.values()
#
# Returns list of dictionary dict's values.
