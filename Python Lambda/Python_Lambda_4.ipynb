# %% [markdown]
# <a href="https://colab.research.google.com/github/digitechit07/Python-Tutorial-with-Excercise/blob/main/Python_Lambda_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **How to Use Lambda Functions**
# This section covers the basics of how to create and use lambda functions, including their syntax and how to use them as arguments in higher-order functions such as map, filter, and reduce.
#
# Additionally, this section explores how you can use lambda functions in sorting and in list comprehensions. By the end, you should have a foundational understanding of the basic uses of lambda functions.

# %%
x = lambda a : a + 10

print(x(5))

x = lambda a, b, c : a + b + c

print(x(5, 6, 2))

def greet(name):
    return "Hello " + name
print(greet("John"))

# Output: "Hello John"

greet = lambda name: "Hello " + name
print(greet("John"))

# Output: "Hello John"

numbers = [1, 2, 3, 4, 5]
squared_numbers = list(map(lambda x: x**2, numbers))
print(squared_numbers)

# Output: [1, 4, 9, 16, 25]

numbers = [1, 2, 3, 4, 5]
even_numbers = list(filter(lambda x: x % 2 == 0, numbers))
print(even_numbers)

# Output: [2, 4]

def make_adder(x):
    return lambda y: x + y
add5 = make_adder(5)
print(add5(3))

# Output: 8

numbers = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]
sorted_numbers = sorted(numbers, key=lambda x: -x)
print(sorted_numbers)

# Output: [9, 6, 5, 5, 5, 4, 3, 3, 2, 1, 1]
from functools import reduce
numbers = [1, 2, 3, 4, 5]
product = reduce(lambda x, y: x*y, numbers)
print(product)

# Output: 120

numbers = [1, 2, 3, 4, 5]
even_numbers = list(filter(lambda x: x % 2 == 0, numbers))
print(even_numbers)

# Output: [2, 4]

employees = [{"name": "John", "age": 32},              {"name": "Jane", "age": 27},              {"name": "Jim", "age": 40}]
sorted_employees = sorted(employees, key=lambda x: x["age"])
print(sorted_employees)

# Output: [{"name": "Jane", "age": 27},
#          {"name": "John", "age": 32},
#          {"name": "Jim", "age": 40}]


employees = [{"name": "John", "salary": 50000}, {"name": "Jane", "salary": 55000}, {"name": "Jim", "salary": 60000}]
highest_salary_employee = max(employees, key=lambda x: x["salary"])
print(highest_salary_employee)

# Output: {"name": "Jim", "salary": 60000}

import tkinter as tk

def on_button_click():
    print("Button clicked!")
'''
root = tk.Tk()
button = tk.Button(root, text="Click Me!", command=lambda: print("Button clicked!"))
button.pack()
root.mainloop()

square = lambda x: x * x
print(square(5))
'''
# Output: 25

calculate = lambda x, y: x + y if x > y else x - y
print(calculate(5, 10))

# Output: -5

def calculate(x, y):
    if x > y:
        return x + y
    else:
        return x - y

print(calculate(5, 10))

# Output: -5

# This lambda function returns the square of its input
square = lambda x: x * x
print(square(5))

# Output: 25

# This lambda function returns the sum of its inputs
sum = lambda x, y: x + y
print(sum(5, 10))

# Output: 15

square = lambda x: x ** 2
print(square(5))


even_or_odd = lambda x: "Even" if x % 2 == 0 else "Odd"
print(even_or_odd(7))


max_value = lambda a, b: a if a > b else b
print(max_value(10, 25))
nums = [1, 2, 3, 4]
squares = [(lambda x: x ** 2)(n) for n in nums]
print(squares)
names = ["Alice", "Bob", "Anna", "Tom"]
a_names = [name for name in names if (lambda x: x.startswith('A'))(name)]
print(a_names)

numbers = [1, 2, 3, 4]
doubled = list(map(lambda x: x * 2, numbers))
print(doubled)
numbers = [1, 2, 3, 4, 5, 6]
evens = list(filter(lambda x: x % 2 == 0, numbers))
print(evens)

from functools import reduce
numbers = [1, 2, 3, 4]
product = reduce(lambda x, y: x * y, numbers)
print(product)


raise_to_power = lambda x, y: x ** y

raise_to_power(2, 3)


nums = [48, 6, 9, 21, 1]

square_all = map(lambda num: num ** 2, nums)

print(square_all)


def echo_word(word1, echo):
    """Concatenate echo copies of word1."""
    words = word1 * echo
    return words


# Define echo_word as a lambda function: echo_word
echo_word = (lambda word1, echo: word1 * echo)

# Call echo_word: result
result = echo_word('hey', 5)

# Print result
print(result)

# Regular function to find the average of three numbers
def average(x, y, z):
    return (x + y + z) / 3

# Lambda function to find the average of three numbers
average = lambda x, y, z: (x + y + z) / 3

concat_and_uppercase = lambda str1, str2: (f'The concatenated string is {str1 + str2}'.upper())

print(concat_and_uppercase("hello", "world"))  # Output: THE CONCATENATED STRING IS HELLOWORLD

# List of pairs of numbers
pairs = [(2, 3), (4, 5), (6, 7)]

# Using lambda function with map to multiply each pair and print the result
list(map(lambda pair: print(f'{pair[0]} * {pair[1]} = {pair[0] * pair[1]}'), pairs))

# List of ages
ages = [25, 30, 18, 42, 17, 50, 22, 19]

# Function to filter adults (age 18 and above) using filter with lambda
adults = filter(lambda age: age >= 18, ages)
print(list(adults))  # Output: [25, 30, 18, 42, 50, 22, 19]

from functools import reduce

# List of numbers
numbers = [1, 2, 3, 4, 5]

# Using reduce with lambda to sum the numbers
sum_of_numbers = reduce(lambda x, y: x + y, numbers)
print(sum_of_numbers)  # Output: 15

cities = ["India", "Germany", "America", "Japan"]
sorted_cities = sorted(cities, key=lambda city: city.lower())

print(sorted_cities)  # Output: ['America', 'Germany', 'India', 'Japan']
# Out:
# 15
# 13
# Hello John
# Hello John
# [1, 4, 9, 16, 25]
# [2, 4]
# 8
# [9, 6, 5, 5, 5, 4, 3, 3, 2, 1, 1]
# 120
# [2, 4]
# [{'name': 'Jane', 'age': 27}, {'name': 'John', 'age': 32}, {'name': 'Jim', 'age': 40}]
# {'name': 'Jim', 'salary': 60000}
# -5
# -5
# 25
# 15
# 25
# Odd
# 25
# [1, 4, 9, 16]
# ['Alice', 'Anna']
# [2, 4, 6, 8]
# [2, 4, 6]
# 24
# <map object at 0x7e1845b5af50>
# heyheyheyheyhey
# THE CONCATENATED STRING IS HELLOWORLD
# 2 * 3 = 6
# 4 * 5 = 20
# 6 * 7 = 42
# [25, 30, 18, 42, 50, 22, 19]
# 15
# ['America', 'Germany', 'India', 'Japan']

# %% [markdown]
# # **How to use lambda functions as arguments in higher-order functions (map, filter, reduce)**
# Lambda functions are often used as arguments in higher-order functions such as map, filter, and reduce. These functions allow you to apply a given operation to every element of a list or other iterable.

# %%
# List of numbers
numbers = [1, 2, 3, 4, 5]

# Using lambda in list comprehension to square each number
squared_numbers = [(lambda x: x ** 2)(x) for x in numbers]
print(squared_numbers)  # Output: [1, 4, 9, 16, 25]

import pandas as pd

data = [
    ("Sapiens", "Yuval Harari", 4.6, 2011),
    ("Homo Deus", "Yuval Harari", 4.4, 2015),
    ("Educated", "Tara Westover", 4.5, 2018),
    ("The Selfish Gene", "Richard Dawkins", 4.2, 1976),
    ("Cosmos", "Carl Sagan", 4.5, 1980),
    ("The Gene", "Siddhartha Mukherjee", 4.3, 2016),
    ("The Martian", "Andy Weir", 4.4, 2014),
    ("Contact", "Carl Sagan", 4.3, 1985)
]

books = pd.DataFrame(data, columns=["title", "author", "rating", "year"])
print(books)

add = lambda x, y: x + y

print(add(3, 5))

a = [(1, 2), (4, 1), (9, 10), (13, -3)]
a.sort(key=lambda x: x[1])

print(a)
# Output: [(13, -3), (4, 1), (1, 2), (9, 10)]

add_10 = lambda x: x + 10
print(add_10(5))

multiply = lambda x, y: x * y
print(multiply(3, 4))

numbers = [1, 2, 3, 4]
squared = map(lambda x: x**2, numbers)
print(list(squared))

numbers = [1, 2, 3, 4, 5, 6]
even_numbers = filter(lambda x: x % 2 == 0, numbers)
print(list(even_numbers))

pairs = [(1, 3), (2, 2), (4, 1)]
pairs.sort(key=lambda x: x[1])
print(pairs)

print((lambda x, y: x + y)(5, 7))

numbers = [3, 5, 9, 12, 15, 20]
divisible_by_3 = filter(lambda x: x % 3 == 0, numbers)
print(list(divisible_by_3))

add = lambda a: a + a
print(add(20))  # prints 40

# Single argument
increment = lambda x: x + 1
print(increment(5))  # Output: 6

# Multiple arguments
add = lambda a, b: a + b
print(add(3, 7))     # Output: 10

squared = list(map(lambda x: x * x, [1, 2, 3, 4]))
print(squared)  # [1, 4, 9, 16]

evens = list(filter(lambda x: x % 2 == 0, range(10)))
print(evens)  # [0, 2, 4, 6, 8]

words = ["apple", "banana", "cherry"]
sorted_by_last = sorted(words, key=lambda w: w[-1])
print(sorted_by_last)  # sorted by last letter

# A lambda function to find the square of a number
square = lambda n: n * n
num = square(5)
print(num)  # Output: 25

# A lambda function for subtracting numbers
sub = lambda x, y: x - y
print(sub(5, 3))  # Output: 2

myList = [10, 25, 17, 9, 30, -5]
# Double each number
myList2 = map(lambda n: n * 2, myList)
print(myList2)  # Output: [20, 50, 34, 18, 60, -10]

# List of strings
strings = ["apple", "banana", "orange", "kiwi"]

# Using map to get the length of each string
string_lengths = map(len, strings)

# Converting the map object to a list
string_lengths_list = list(string_lengths)

print(string_lengths_list)  # Output: [5, 6, 6, 4]

# Lists of numbers
numbers1 = [1, 2, 3, 4, 5]
numbers2 = [6, 7, 8, 9, 10]

# Using map to calculate the squares of corresponding elements
squared_numbers = map(lambda x, y: x * y, numbers1, numbers2)

# Converting the map object to a list
squared_numbers_list = list(squared_numbers)

print(squared_numbers_list)  # Output: [6, 14, 24, 36, 50]

# Lists of first and last names
first_names = ["John", "Emma", "Michael"]
last_names = ["Doe", "Smith", "Johnson"]

# Using map to combine first and last names
full_names = map(lambda x, y: x + " " + y, first_names, last_names)

# Converting the map object to a list
full_names_list = list(full_names)

print(full_names_list)  # Output: ['John Doe', 'Emma Smith', 'Michael Johnson']

square = lambda x: x**2  # returns a function object
print(square(5))  # Output: 25

# Using lambda to define a simple function
double = lambda x: x * 2
print(double(5))  # Output: 10

# Using def to define a more complex function
def double(x):
    return x * 2
print(double(5))  # Output: 10

numbers = [1, 2, 3, 4, 5]
squared_numbers = list(map(lambda x: x**2, numbers))
print(squared_numbers)  # Output: [1, 4, 9, 16, 25]

numbers = [1, 2, 3, 4, 5]
even_numbers = list(filter(lambda x: x % 2 == 0, numbers))
print(even_numbers)  # Output: [2, 4]

strings = ['apple', 'banana', 'cherry', 'date']
sorted_strings = sorted(strings, key=lambda x: len(x))
print(sorted_strings)  # Output: ['date', 'apple', 'cherry', 'banana']

from functools import reduce

numbers = [1, 2, 3, 4, 5]
sum_of_numbers = reduce(lambda x, y: x + y, numbers)
print(sum_of_numbers)  # Output: 15

list1 = [1, 2, 3]
list2 = ['a', 'b', 'c']
combined = list(zip(list1, list2))
print(combined)  # Output: [(1, 'a'), (2, 'b'), (3, 'c')]

numbers = [1, 2, 3, 4, 5]
indexed_numbers = list(enumerate(numbers))
print(indexed_numbers)  # Output: [(0, 1), (1, 2), (2, 3), (3, 4), (4, 5)]

from itertools import groupby

numbers = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]
grouped_numbers = [(k, len(list(g))) for k, g in groupby(numbers)]
print(grouped_numbers)  # Output: [(1, 1), (2, 2), (3, 3), (4, 4)]

from functools import reduce

numbers = [1, 2, 3, 4, 5]
sum_of_numbers = reduce(lambda x, y: x + y, numbers)
print(sum_of_numbers)  # Output: 15

adder = lambda x: (lambda y: x**2 + y**2)
print(adder(10)(5))  # 125

fibonacci_generator = lambda n: (lambda x: x if n <= 1 else fibonacci_generator(n-1)(x-1) + fibonacci_generator(n-2)(x-2))
fibonacci = fibonacci_generator(10)
print(fibonacci(10))  # 55

sign = lambda n: 'positive' if n > 0 else 'zero' if n == 0 else 'negative'
print(sign(-4))  # negative

categorize_student = lambda grade: 'Distinction' if grade >= 90 else 'Merit' if grade >= 80 else 'Pass' if grade >= 70 else 'Fail'
students = [
    {'name': 'Alice', 'grade': 95},
    {'name': 'Bob', 'grade': 75},
    {'name': 'Charlie', 'grade': 60},
    {'name': 'David', 'grade': 85}
]

for student in students:
    print(f"{student['name']}: {categorize_student(student['grade'])}")

import timeit

# Measuring the execution time of a lambda function
lambda_time = timeit.timeit("(lambda x: x+1)(5)", number=1_000_000)

# Measuring the execution time of a regular function defined with 'def'
def_time = timeit.timeit("def f(x):\n return x+1\nf(5)", number=1_000_000)

# Printing the results
print(f"Lambda function time: {lambda_time}")
print(f"Def function time: {def_time}")
# Out:
# [1, 4, 9, 16, 25]
#               title                author  rating  year
# 0           Sapiens          Yuval Harari     4.6  2011
# 1         Homo Deus          Yuval Harari     4.4  2015
# 2          Educated         Tara Westover     4.5  2018
# 3  The Selfish Gene       Richard Dawkins     4.2  1976
# 4            Cosmos            Carl Sagan     4.5  1980
# 5          The Gene  Siddhartha Mukherjee     4.3  2016
# 6       The Martian             Andy Weir     4.4  2014
# 7           Contact            Carl Sagan     4.3  1985
# 8
# [(13, -3), (4, 1), (1, 2), (9, 10)]
# 15
# 12
# [1, 4, 9, 16]
# [2, 4, 6]
# [(4, 1), (2, 2), (1, 3)]
# 12
# [3, 9, 12, 15]
# 40
# 6
# 10
# [1, 4, 9, 16]
# [0, 2, 4, 6, 8]
# ['banana', 'apple', 'cherry']
# 25
# 2
# <map object at 0x7e1845b7be80>
# [5, 6, 6, 4]
# [6, 14, 24, 36, 50]
# ['John Doe', 'Emma Smith', 'Michael Johnson']
# 25
# 10
# 10
# [1, 4, 9, 16, 25]
# [2, 4]
# ['date', 'apple', 'banana', 'cherry']
# 15
# [(1, 'a'), (2, 'b'), (3, 'c')]
# [(0, 1), (1, 2), (2, 3), (3, 4), (4, 5)]
# [(1, 1), (2, 2), (3, 3), (4, 4)]
# 15
# 125
# 55
# negative
# Alice: Distinction
# Bob: Pass
# Charlie: Fail
# David: Merit
# Lambda function time: 0.11818111099989892
# Def function time: 0.12404745300000286

# %% [markdown]
# # **How to use lambda functions with reduce**
# The reduce function is a higher-order function that takes a binary function (a function that takes two arguments) and a list. It returns a single value that is the result of applying the binary function to the elements of the list in a cumulative way.

# %%
# Using a lambda function as an argument to the sorted function
numbers = [1, 4, 2, 3]
sorted_numbers = sorted(numbers, key=lambda x: x**2)
print(sorted_numbers)  # [1, 2, 3, 4]

# Defining a named function with def
def square(x):
    return x**2

# Defining an anonymous function with lambda
lambda_square = lambda x: x**2

# Using a lambda function as a decorator
def lambda_decorator(func):
    return lambda *args, **kwargs: func(*args, **kwargs)

@lambda_decorator
def example_function():
    print("This function has been decorated with a lambda.")

# This is not allowed
lambda x: (x**2 for x in range(10))

# Instead, use a generator function
def square_generator():
    for x in range(10):
        yield x**2

print(list(map(lambda x:
            x*x,
            [1,2,3])))

print(list(map(lambda x:
          "True" if (x%2 == 0)
          else "False",
          [1,2,3])))

print(list(map(lambda x:  \
          "True" if (x%2 == 0)  \
          else "False",
          [1,2,3])))

def add_numbers(a, b):
    return a + b

## Calling the function
result = add_numbers(5, 3)
print(result)  ## Output: 8

'''
def calculate_stats(numbers):
    total = sum(numbers)
    average = total / len(numbers)
    return total, average

## Unpacking returned values
sum_result, avg_result = calculate_stats([1, 2, 3, 4, 5])
'''
def complex_calculation(x, y):
    ## First line of function body
    result = x * 2

    ## Multiple lines of processing
    if result > 10:
        result += y
    else:
        result -= y

    ## Final calculation and return
    final_result = result ** 2
    return final_result

def advanced_function(param1, param2):
    """
    Multiline function with comprehensive documentation.

    Args:
        param1 (int): First input parameter
        param2 (str): Second input parameter

    Returns:
        dict: Processed result
    """
    ## Function implementation
    result = {
        'processed_value': param1,
        'description': param2
    }
    return result

def complex_decision_maker(data):
    ## Multiple condition branches
    if data > 100:
        ## First processing path
        result = data * 2
    elif data > 50:
        ## Alternative processing path
        result = data + 50
    else:
        ## Default processing
        result = data / 2

    return result

def safe_division(a, b):
    try:
        ## Multiple line calculation with error protection
        result = a / b
        rounded_result = round(result, 2)
        return rounded_result
    except ZeroDivisionError:
        return "Cannot divide by zero"
    except TypeError:
        return "Invalid input types"

## Traditional function
def square(x):
    return x ** 2

## Equivalent lambda function
square_lambda = lambda x: x ** 2

## Using lambda with built-in functions
numbers = [1, 2, 3, 4, 5]
squared_numbers = list(map(lambda x: x ** 2, numbers))

def performance_tracker(func):
    def wrapper(*args, **kwargs):
        import time
        start = time.time()
        result = func(*args, **kwargs)
        end = time.time()
        print(f"Function {func.__name__} took {end - start} seconds")
        return result
    return wrapper

@performance_tracker
def complex_calculation(n):
    return sum(range(n))

def fibonacci_generator(n):
    a, b = 0, 1
    for _ in range(n):
        yield a
        a, b = b, a + b

## Memory-efficient iteration
fib_sequence = list(fibonacci_generator(10))

from typing import List, Dict, Optional

def process_data(
    items: List[int],
    multiplier: Optional[float] = 1.0
) -> Dict[str, float]:
    processed = [item * multiplier for item in items]
    return {
        'original': len(items),
        'processed_sum': sum(processed)
    }

from functools import reduce

## Combining functional programming concepts
def advanced_data_processing(numbers):
    ## Chaining operations
    result = (
        reduce(lambda x, y: x + y,
               filter(lambda n: n % 2 == 0, numbers))
    )
    return result

def stateful_def():
    foo = 10
    bar = foo * foo
    foo = 2
    return foo + bar

stateful_lambda = (lambda state: lambda *_: (state.setdefault('foo', 10),
                                             state.setdefault('bar', state.get('foo') * state.get('foo')),
                                             state.pop('foo'),
                                             state.setdefault('foo', 2),
                                             state.get('foo') + state.get('bar'))[-1])({})

# Mimicking "multiple results" with a single expression
process_values = lambda x, y: (x + y, x * y, x - y)
sum_prod_diff = process_values(10, 5) # (15, 50, 5)

distance = lambda a, b: ((a[0] - b[0]) ** 2 + (a[1] - b[1]) ** 2) ** 0.5

distance((0, 5), (1, 1))

f = lambda x: x + 5
print('Hello')

a = ['Hello', 'Bye', 'My', 'Lovely', 'Incorporation', 'Hi']
b = [(0, 5), (2, -1), (10, 5), (2, -5), (0, 0), (-1, 1)]

def get_length(item):
   return len(item)

def get_second_item(item):
   return item[1]

a.sort(key=get_length)
b.sort(key=get_second_item)

print(a)
print(b)
# Out:
# [1, 2, 3, 4]
# [1, 4, 9]
# ['False', 'True', 'False']
# ['False', 'True', 'False']
# 8
# Hello
# ['My', 'Hi', 'Bye', 'Hello', 'Lovely', 'Incorporation']
# [(2, -5), (2, -1), (0, 0), (-1, 1), (0, 5), (10, 5)]

# %% [markdown]
# # **Limitations of Lambda Functions**
# While lambda functions are a convenient way to write short and simple functions, they have some limitations.
#
# One of the main limitations is that lambda functions are limited to a single expression, meaning that they cannot contain multiple statements or complex control flow.
#
# In addition, lambda functions cannot be referenced by name and can only be invoked when they are defined, which makes them less flexible than named functions.
#
# Another limitation is that lambda functions do not have a name, which can make debugging more difficult and make it harder to understand the code.
#
# In general, it's a good idea to use named functions for complex operations and only use lambda functions for short and simple operations.
