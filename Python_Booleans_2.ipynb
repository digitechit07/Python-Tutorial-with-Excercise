# %% [markdown]
# <a href="https://colab.research.google.com/github/digitechit07/Python-Tutorial-with-Excercise/blob/main/Python_Booleans_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Boolean Operators And Or Not**
# Boolean values can be combined with the operators and or not, like following (printing 'yay' if x is greater than 0, but not 5 :
#
# if x > 0 and x != 5:
#     print('yay')
# Python is unique in using the plain words like "and" for this. many languages use "&&" for and, "||" for or.
#
# A and B → True if both are True
#
# A or B → True if one or the other or both are True
#
# not A → Inverts True/False

# %%
var=True
print(f"The type of {var} is {type(var)}")

var2=False
print(f"The type of {var2} is {type(var2)}")

var2="False"
print(f"The type of {var2} is {type(var2)}")

var_1=bool(4) #boolean of a on zero number
print(f"The type of {var_1} is {type(var_1)}")

var_2=bool([]) #boolean of an empty list
print(f"The type of {var_2} is {type(var_2)}")

bool(0)

bool(0.0000000000001)

bool(0.0j)

bool(" ")

bool("")

bool('PythonGeeks')

bool(())

bool((1,2))

bool([])

bool(['t'])

bool({})

bool({4:'c'})

bool(None)

bool(True)

bool(False)

'e' in 'PythonGeeks'

5 not in [1,3,4,5.0,8]

6.7 in (1,5,'t')

5.0==5

[1,2,3]>[2,3,4]

4.5!=7

'abc'>='ABC'

(1.3,4,78)<(0,5.6,3)

{'a','b'}<={'a','b','d'}

5.0 is 5

'a' is not 'A'

{1,2,3} is {2,3,1}

True+False #1+0

True+False+False+True #1+0+0+1

True+False+False+True+True #1+0+0+1+1

False-True #0-1

True-False+True #1-0+1

True * False #1*0

True * True #1*1

True/True #1/1

#False/True #0/1

#True/False #1/0

True//True #1//1

False//True #0//1

True % True #1%1

#True%False #1%0

True**False #1**0

True**True #1**1

True == False #1==0

True>False #1>0

True != True #1!=1

True>=False #1>=0

False<True #1<0

False<=False#0<=0

True | False #1|0

False & True #0 &1

False ^ False # 0^0

~False #~0

True<<2 #1<<2

False>>3 #0>>3

True and False

False or True

not False

Q1=True
Q2=False
Q3=False
Q4=True
Q5=True

marks = 2*(Q1+Q2+Q3+Q4+Q5)
print(marks)

list1=['a','b']
print(list1[not False])

print(list1[not True])

num=5
num>=1 and num<=10

num=19
num>=1 and num<=10

list1=['abc','pqr','xyz','uvw']
'xyz' in list1

'ertyh' in list1

val1=True
val2=False
val3=True

res=val1*val2*val3
print(bool(res))

val2=True

res=val1*val2*val3
print(bool(res))
# Out:
# The type of True is <class 'bool'>
# The type of False is <class 'bool'>
# The type of False is <class 'str'>
# The type of True is <class 'bool'>
# The type of False is <class 'bool'>
# 6
# b
# a
# False
# True
# <>:64: SyntaxWarning: "is" with 'float' literal. Did you mean "=="?
# <>:66: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
# <>:64: SyntaxWarning: "is" with 'float' literal. Did you mean "=="?
# <>:66: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
# /tmp/ipython-input-1838248414.py:64: SyntaxWarning: "is" with 'float' literal. Did you mean "=="?
#   5.0 is 5
# /tmp/ipython-input-1838248414.py:66: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
#   'a' is not 'A'

# %% [markdown]
# # **Prerequisites**
# You should have Python 3 installed and a programming environment set up on your computer or server. If you don’t have a programming environment set up, you can refer to the installation and setup guides for a local programming environment or for a programming environment on your server appropriate for your operating system (Ubuntu, CentOS, Debian, etc.)
#
# Comparison Operators
# In programming, comparison operators are used to compare values and evaluate down to a single Boolean value of either True or False.
#
# Info: To follow along with the example code in this tutorial, open a Python interactive shell on your local system by running the python3 command. Then you can copy, paste, or edit the examples by adding them after the >>> prompt.
#
# The table below is of Boolean comparison operators.
#
# Operator	What it means
# ==	Equal to
# !=	Not equal to
# <	Less than
# >	Greater than
# <=	Less than or equal to
# >=	Greater than or equal to

# %%
x = 5
y = 8

print("x == y:", x == y)
print("x != y:", x != y)
print("x < y:", x < y)
print("x > y:", x > y)
print("x <= y:", x <= y)
print("x >= y:", x >= y)

Sammy = "Sammy"
sammy = "sammy"

print("Sammy == sammy: ", Sammy == sammy)

Sammy = "Sammy"
sammy = "sammy"
also_Sammy = "Sammy"

print("Sammy == sammy: ", Sammy == sammy)
print("Sammy == also_Sammy", Sammy == also_Sammy)

t = True
f = False

print("t != f: ", t != f)

x = y	# Sets x equal to y
x == y	# Evaluates whether x is equal to y

print((9 > 7) and (2 < 4))	# Both original expressions are True
print((8 == 8) or (6 != 6))	# One original expression is True
print(not(3 <= 1))			# The original expression is False

print((-0.2 > 1.4) and (0.8 < 3.1))	# One original expression is False
print((7.5 == 8.9) or (9.2 != 9.2))	# Both original expressions are False
print(not(-5.7 <= 0.3))				# The original expression is True

#not((-0.2 > 1.4) and ((0.8 < 3.1) or (0.1 == 0.1)))

grade = 75
if grade >= 65:					# Condition
    print("Passing grade")		# Clause

else:
    print("Failing grade")


is_student  =  True
has_graduated  =  False

print(is_student)
print(has_graduated)

age  =  20
is_adult  =  age  >=  18

print(is_adult)

age  =  18
is_adult  =  age  >=  18

print(f"The person is an adult: {is_adult}")
a  =  5
b  =  5

result  =  a  ==  b

print(f"The result is {result}. This is because {a} and {b} are equal.")

high_score  =  90
good_behavior  =  True
honor_roll  =  high_score  >  85  and  good_behavior

print(honor_roll)


rain  =  False
umbrella  =  True
stay_dry  =  rain  or  umbrella

print(stay_dry)

is_minor  =  17
is_not_adult  =  not (is_minor  >=  18)

print(is_not_adult)

number  =  10
if  number  >  0:
    print("The number is positive.")

number  =  10
if  number  >  0  and  number  %  2  ==  0:
    print("The number is positive and even.")

number  =  0
while  number  <  5:
    print(f"Number is {number}")
    number  +=  1


elements  = [1, 2, 3, 4, 5]
for  element  in  elements:
    if  element  ==  3:
        break
    print(f"Element is {element}")


def  process_data(is_valid):
    if  is_valid:
        print("Data is valid, processing...")
    else:
        print("Data is invalid, skipping...")

data_check  =  10  >  5
process_data(data_check)

def  is_even(number):
    return  number  %  2  ==  0

number_check  =  is_even(42)
print(number_check)
# Out:
# x == y: False
# x != y: True
# x < y: True
# x > y: False
# x <= y: True
# x >= y: False
# Sammy == sammy:  False
# Sammy == sammy:  False
# Sammy == also_Sammy True
# t != f:  True
# True
# True
# True
# False
# False
# False
# Passing grade
# True
# False
# True
# The person is an adult: True
# The result is True. This is because 5 and 5 are equal.
# True
# True
# True
# The number is positive.
# The number is positive and even.
# Number is 0
# Number is 1
# Number is 2
# Number is 3
# Number is 4
# Element is 1
# Element is 2
# Data is valid, processing...
# True

# %% [markdown]
# # **Logical operators**
# Next up: logical operators. These operators only work on booleans and are used to implement logic. The following table lists and describes them:
#
# Operator	What it does	Examples
#
# and	True if both statements are true	True and False == False
# False and False == False
#
# True and True == True
#
# or	True if one of the statements is true	True or False == True
#
# True or True == True
#
# False or False == False
#
# not	Negates the statement that follows	not True == False
#
# not False == True
