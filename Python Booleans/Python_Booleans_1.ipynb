# %% [markdown]
# <a href="https://colab.research.google.com/github/digitechit07/Python-Tutorial-with-Excercise/blob/main/Python_Booleans_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Python booleans represent one of the fundamental data types**
# Used to express the truth value of an expression. They have only two possible values: True or False. These values are keywords in Python and must be written with an initial capital letter.
# Key characteristics of Python Booleans:
# Two Values: Booleans can only be True or False.
# Built-in Type: They are a built-in data type, represented by the bool class.
# Subclass of Integers: bool is a subclass of int. This means True evaluates to 1 and False evaluates to 0 when used in numerical contexts.
# Usage in Conditionals: Booleans are essential for controlling program flow through conditional statements like if, elif, and else.
# Logical Operators: They are combined and manipulated using logical operators: and, or, and not.
# Comparison Operators: Comparison operators (e.g., ==, !=, <, >) return boolean values based on the comparison of operands.
# bool() Function: The built-in bool() function can convert other data types to booleans. In this conversion, generally, empty values (empty strings, lists, tuples, dictionaries, None, and the number 0) are considered False, while non-empty or non-zero values are considered True.

# %%
# Assigning boolean values
is_active = True
has_permission = False

# Using booleans in conditional statements
if is_active:
    print("User is active.")
else:
    print("User is inactive.")

# Using logical operators
if is_active and has_permission:
    print("User is active and has permission.")

# Comparison operators returning booleans
x = 10
y = 5
print(x > y)  # Output: True

# Using the bool() function
print(bool("Hello"))  # Output: True
print(bool(""))      # Output: False
print(bool(0))       # Output: False
print(bool(5))       # Output: True



print(10 > 9)
print(10 == 9)
print(10 < 9)

a = 200
b = 33

if b > a:
  print("b is greater than a")
else:
  print("b is not greater than a")

print(bool("Hello"))
print(bool(15))

x = "Hello"
y = 15

print(bool(x))
print(bool(y))

bool("abc")
bool(123)
bool(["apple", "cherry", "banana"])

bool(False)
bool(None)
bool(0)
bool("")
bool(())
bool([])
bool({})

class myclass():
  def __len__(self):
    return 0

myobj = myclass()
print(bool(myobj))

def myFunction() :
  return True

if myFunction():
  print("YES!")
else:
  print("NO!")

x = 200
print(isinstance(x, int))
# Out:
# User is active.
# True
# True
# False
# False
# True
# True
# False
# False
# b is not greater than a
# True
# True
# True
# True
# False
# YES!
# True

# %% [markdown]
# # **Python Boolean**
#
# Python Boolean type is one of the built-in data types provided by Python, which represents one of the two values i.e. True or False. Generally, it is used to represent the truth values of the expressions.

# %%
a = True
print(type(a))

b = False
print(type(b))

# Returns False as x is None
x = None
print(bool(x))

# Returns False as x is an empty sequence
x = ()
print(bool(x))

# Returns False as x is an empty mapping
x = {}
print(bool(x))

# Returns False as x is 0
x = 0.0
print(bool(x))

# Returns True as x is a non empty string
x = 'GeeksforGeeks'
print(bool(x))

var1 = 0
print(bool(var1))

var2 = 1
print(bool(var2))

var3 = -9.7
print(bool(var3))

a = 5
b = 3
c = 8

if a > b or b < c:
    print("True")

a = 0
b = 2
c = 4

if a > b and b<c:
    print(True)
else:
    print(False)

if a and b and c:
    print("True")
else:
    print("False")

a = 0

if not a:
    print("False")

a = 0
b = 1

if a == 0:
    print(True)

if a == b:
    print(True)

if a != b:
    print(True)


x = 10
y = 10

if x is y:
    print(True)
else:
    print(False)

# Create a list
a = [1, 2, 2]

# Check if lion in list or not
if 1 in a:
    print(True)
# Out:
# <class 'bool'>
# <class 'bool'>
# False
# False
# False
# False
# True
# False
# True
# True
# True
# False
# False
# False
# True
# True
# True
# True

# %% [markdown]
# # **Boolean in Python**
# If you want to define a boolean in Python, you can simply assign a True or False value or even an expression that ultimately evaluates to one of these values.

# %%
is_active = True  # Direct assignment
is_positive = -1 > 0  # Result of a comparison, evaluates to False

user_age = 20
if user_age >= 18:
    print("You are eligible to vote.")  # This block executes if the condition is True
else:
    print("You are not eligible to vote.")


age = 25

# Multiple comparisons combined with a logical operator
if age >= 65:
    print("Eligible for senior benefits.")  # This line won't execute because one comparison is False
else:
    print("Not eligible for senior benefits.")

count = 0
while count < 5:
    print(count)
    count += 1  # This loop prints numbers from 0 to 4

a = True
b = False
result1 = a and b  # False because both operands are not True
result2 = a or b # True because one operand is True
result3 = a and not b  # True because a is True and b is not True

is_logged_in = True
if is_logged_in:
    print("Access granted.")
else:
    print("Please log in.")

def is_valid_age(age):
    return 0 < age < 120  # Ensures age is within a reasonable range

print(is_valid_age(25))  # Outputs: True

feature_enabled = False
if feature_enabled:
    print("New feature is enabled.")
else:
    print("New feature is currently disabled.")

level_complete = True
if level_complete:
    print("Congratulations! Moving to the next level.")

has_high_score = True
has_extra_lives = False

if has_high_score and not has_extra_lives:
    print("High score, but no extra lives!")

if []:  # An empty list is "falsy"
    print("Won't print")
else:
    print("An empty list is considered False")

print(bool(0))  # Outputs: False, because 0 is considered "Falsy"
print(bool(42))  # Outputs: True, because non-zero numbers are "Truthy"
print(bool(""))  # Outputs: False, because an empty string is "Falsy"

is_online = True
has_subscription = True

# Both variables need to be True
can_access_content = is_online and has_subscription
print(can_access_content)  # Output: True

is_admin = False
has_special_access = True

# Only one variable needs to be True
can_edit = is_admin or has_special_access
print(can_edit)  # Output: True

is_restricted = False

# Inverts the boolean value
can_proceed = not is_restricted
print(can_proceed)  # Output: True

def is_even(number):
    return number % 2 == 0

if is_even(4):
    print("Number is even.")
else:
    print("Number is odd.")
# Out:
# You are eligible to vote.
# Not eligible for senior benefits.
# 0
# 1
# 2
# 3
# 4
# Access granted.
# True
# New feature is currently disabled.
# Congratulations! Moving to the next level.
# High score, but no extra lives!
# An empty list is considered False
# False
# True
# False
# True
# True
# True
# Number is even.

# %% [markdown]
# # **Python Booleans (bool)**
# In Python, bool is a sub-type of int type. A bool object has two possible values, and it is initialized with Python keywords, True and False.

# %%
a=int(True)
print ("bool to int:", a)
a=float(False)
print ("bool to float:", a)
a=complex(True)
print ("bool to complex:", a)

# Check true
a = True
print(bool(a))
# Check false
a = False
print(bool(a))
# Check 0
a = 0.0
print(bool(a))
# Check 1
a = 1.0
print(bool(a))
# Check Equality
a = 5
b = 10
print(bool( a==b))
# Check None
a = None
print(bool(a))
# Check an empty sequence
a = ()
print(bool(a))
# Check an emtpty mapping
a = {}
print(bool(a))
# Check a non empty string
a = 'Tutorialspoint'
print(bool(a))
# Out:
# bool to int: 1
# bool to float: 0.0
# bool to complex: (1+0j)
# True
# False
# False
# True
# False
# False
# False
# False
# True

# %% [markdown]
# # **Boolean Expressions**
# The Python "bool" type (short for "boolean") has only two values - True and False. The bool values typically show up in the tests of if-statements and while-loops.
#
# # **Boolean Comparisons**
# Usually a bool is created by comparing two values — e.g. x == y returns True if the values are equal, like this:
#
# 1 == 2 → FalseEqual
#
# 1 != 2 → TrueNot equal
#
# 1 < 2 → TrueStrict less than
#
# 2 < 2 → FalseStrict less than
#
# 2 <= 2 → TrueLess or equal
#
# Unlike many languages, the == and != operators work for any data type — int, string, list, and so on.
