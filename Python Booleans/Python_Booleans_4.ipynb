# %% [markdown]
# <a href="https://colab.research.google.com/github/digitechit07/Python-Tutorial-with-Excercise/blob/main/Python_Booleans_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Python Booleans**
# We will learn about Python booleans with the help of examples.
#
# A Boolean expression is an expression that evaluates to either True or False. For example,

# %%
result1 = True
result2 = False

print(result1) # True
print(result2) # False

number = 5
print(number < 10) # True

number = 15
print(number < 10) # False

# comparison operators in action

number = 15
print(number > 10) # True

number = 10
print(number > 10) # False

number = 10
# equal to
print(number == 10) # True

number = 10.0
# comparing float and integer
print(number == 10) # True

number = '10'
# comparing string and integer
print(number == 10) # False

number = '10'
# not equal to
print(number != 10) # True

number = 10
# less than or equal to
print(number <= 10) # True

number = 10
# greater than or equal to
print(number >= 10) # True

age = 22
gpa = 3.8

result = age >= 18 and gpa > 3.6
print(result) # True

age = 22
gpa = 3.8

print(age >= 18 and gpa > 3.9) # False

age = 22
gpa = 3.8

print(age >= 18 or gpa > 3.9) # True

print(age <= 18 or gpa > 3.9) # False

result = True
print(result) # True

result = True
print(not result) # False

language = 'Python'
print(language == 'python') # False

age = 18
print(age >= 18) # True
print(age > 18) # False

print(age >= 18 and language == 'Java') # False

n1 = 60
n2 = 80
n3 = 50

if n1 < n2 and n3:
    print(n1)
elif n2 < n1 and n3:
    print(n2)
else:
    print(n3)
# Out:
# True
# False
# True
# False
# True
# False
# True
# True
# False
# True
# True
# True
# True
# False
# True
# False
# True
# False
# False
# True
# False
# False
# 60

# %% [markdown]
# # **What is Boolean Value?**
# In Python Programming, an expression will get a result either as True or False. Expression will be checked in Python and True or False will be produced.
#
# Look at the example given below to know the comparison of two boolean values and how the expression is evaluated in Python.

# %%
print(8 > 7)
print(8== 7)
print(8< 7)

# Two numbers for comparison
number_1 = 10
number_2 = 5

# Checking the condition
if number_1 > number_2:
    message = f"{number_1} is greater than {number_2}."
else:
    message = f"{number_1} is not greater than {number_2}."

# Output
print("Number 1:", number_1)
print("Number 2:", number_2)
print(message)

# Value to be checked
my_value = "Hello"

# Checking the type of the value
if type(my_value) == str:
    message = f"{my_value} is a string."
elif type(my_value) in (int, float):
    message = f"{my_value} is a number."
else:
    message = f"{my_value} is neither a string nor a number."

# Output
print("Value:", my_value)
print(message)


# Two variables for evaluation
variable_1 = 10
variable_2 = 20

# Checking the condition
if variable_1 == variable_2:
    message = f"The variables are equal: {variable_1} == {variable_2}"
else:
    message = f"The variables are not equal: {variable_1} != {variable_2}"

# Output
print("Variable 1:", variable_1)
print("Variable 2:", variable_2)
print(message)

bool("abc")
bool(123)
bool(["apple", "cherry", "banana"])

bool(False)
bool(None)
bool(0)
bool("")
bool(())
bool([])
bool({})

def myFunction() :
  return True

if myFunction():
  print("YES!")
else:
  print("NO!")

print(True and True)
# True

print(True and False)
# False

print(False and True)
# False

print(False and False)
# False

a = 10
print(0 < a)
# True

print(a < 100)
# True

print(0 < a and a < 100)
# True

print(0 < a < 100)
# True

print(True or True)
# True

print(True or False)
# True

print(False or True)
# True

print(False or False)
# False

print(not True)
# False

print(not False)
# True

print(True or True and False)
# True

print(True or (True and False))

print((True or True) and False)
# False

print(bool(10))
# True

print(bool(0))
# False

print(bool(''))
# False

print(bool('0'))
# True

print(bool('False'))
# True

print(bool([]))
# False

print(bool([False]))
# True

x = 10  # Evaluated as true
y = 0   # Evaluated as false

print(x and y)
# 0

print(x or y)
# 10

print(not x)
# False

x = 10   # Evaluated as true
y = 100  # Evaluated as true

print(x and y)
# 100

print(y and x)
# 10

print(x or y)
# 10

print(y or x)
# 100

x = 0    # Evaluated as false
y = 0.0  # Evaluated as false

print(x and y)
# 0

print(y and x)
# 0.0

print(x or y)
# 0.0

print(y or x)
# 0

print(bool(x and y))
# False

def test():
    print('function is called')
    return True

print(True and test())
# function is called
# True

print(False and test())
# False

print(True or test())
# True

print(False or test())
# function is called
# True
# Out:
# True
# False
# False
# Number 1: 10
# Number 2: 5
# 10 is greater than 5.
# Value: Hello
# Hello is a string.
# Variable 1: 10
# Variable 2: 20
# The variables are not equal: 10 != 20
# YES!
# True
# False
# False
# False
# True
# True
# True
# True
# True
# True
# True
# False
# False
# True
# True
# True
# False
# True
# False
# False
# True
# True
# False
# True
# 0
# 10
# False
# 100
# 10
# 10
# 100
# 0
# 0.0
# 0.0
# 0
# False
# function is called
# True
# False
# True
# function is called
# True

# %% [markdown]
# # **Contents**
# and (Logical AND)
#
# or (Logical OR)
#
# not (Negation)
#
# Precedence of and, or, not
#
# Boolean operators with non-bool objects
# and and or do not always return bool values
# Short-circuit evaluation
