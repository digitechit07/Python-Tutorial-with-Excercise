# %% [markdown]
# <a href="https://colab.research.google.com/github/digitechit07/Python-Tutorial-with-Excercise/blob/main/Python_Operators_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **The Hierarchy**
# Just like in our kitchen scenario, Python has a hierarchy of operations. Some operations are performed before others. Here’s a simplified order:
#
# Parentheses: Anything in parentheses is done first. It’s like reading a book – you finish reading the content inside the brackets before moving on.
# Exponential: Next comes the exponential operator (**). It’s like the oven in our kitchen – you need to bake the bread before you can serve the meal.
# Multiplication, Division, Floor Division, and Modulus: These are like the chopping and stirring in our kitchen scenario. They’re the basic tasks that need to be done before the dish can come together.
# Addition and Subtraction: These are the final touches, like adding seasoning to the dish.

# %%
a = 5

b = 3

sum = a + b

print(sum)

a = 5

b = 3

difference = a - b

print(difference)

a = 5

b = 3

product = a * b

print(product)

a = 10

b = 2

quotient = a / b

print(quotient)

a = 10

b = 3

remainder = a % b

print(remainder)

a = 2

b = 3

result = a ** b

print(result)

a = 10

b = 3

result = a // b

print(result)

a = 5

a += 3

print(a)

a = 5

a -= 3

print(a)

a = 5

a *= 3

print(a)

a = 10

a /= 2

print(a)

a = 10

a %= 3

print(a)

a = 2

a **= 3

print(a)

a = 10

a //= 3

print(a)

a = 5

b = 5

result = a == b

print(result)

a = 5

b = 3

result = a != b

print(result)

a = 5

b = 3

result = a > b

print(result)

a = 5

b = 3

result = a < b

print(result)

a = 5

b = 5

result = a >= b

print(result)

a = True

b = False

result = a and b

print(result)

a = True

b = False

result = a or b

print(result)

a = True

result = not a

print(result)

a = 5 # Binary: 101

b = 3 # Binary: 011

result = a & b# Binary: 001

print(result)

a = 5 # Binary: 101

b = 3 # Binary: 011

result = a | b # Binary: 111

print(result)

a = 5 # Binary: 101

b = 3 # Binary: 011

result = a ^ b # Binary: 110

print(result)

a = 5 # Binary: 101

result = ~a # Binary: -110 (Two's complement representation)

print(result)

a = 5 # Binary: 101

result = a << 2 # Binary: 10100

print(result)

a = 5 # Binary: 101

result = a >> 2 # Binary: 1

print(result)

a = [1, 2, 3, 4, 5]

result = 3 in a

print(result)

a = [1, 2, 3, 4, 5]

result = 6 not in a

print(result)


a = [1, 2, 3]

b = a

result = a is b

print(result)

a = [1, 2, 3]

b = [1, 2, 3]

result = a is not b

print(result)
# Out:
# 8
# 2
# 15
# 5.0
# 1
# 8
# 3
# 8
# 2
# 15
# 5.0
# 1
# 8
# 3
# True
# True
# True
# False
# True
# False
# True
# False
# 1
# 7
# 6
# -6
# 20
# 1
# True
# True
# True
# True

# %% [markdown]
# # **Operators Precedence**
# Operator precedence defines order in which Python evaluates different operators in an expression. When an expression has multiple operators, Python follows precedence rules to decide order of evaluation.

# %%
# Precedence of '+' & '*'
expr = 10 + 20 * 30
print(expr)

# Precedence of 'or' & 'and'
name = "Alex"
age = 0
if name == "Alex" or name == "John" and age >= 2:
    print("Hello! Welcome.")
else:
    print("Good Bye!!")

# Division and multiplication
print(100 / 10 * 10)
# Addition and subtraction
print(5 - 2 + 3)
print(5 - (2 + 3))

# Exponentiation is right-to-left
print(2 ** 3 ** 2)

expression = 100 + 200 / 10 - 3 * 10
print(expression)

a = 5
b = 10
c = 15
#a = b = (a < b) += (b < c)

# Addition
print(5 + 2)

# Subtraction
print(5 - 2)

# Multiplication
print(5 * 2)

# Division
print(5 / 2)


# Exponent
print(5 ** 2)
# This is the same as 5 * 5

# Floor Division
print(5 // 2)

# Modulus
print(5 % 2)


firstName = "Théo"

introduction = "Hi, my name is " + firstName + "."

print(introduction)


balance = 100
print(balance)


balance += 10
print(balance)


print(balance)
balance -= 10
print(balance)



a = 3
b = 5

print(a == b) # Equal
print(a != b) # Not equal
print(a > b) # Greater than
print(a < b) # Less than
print(a >= b) # Greater than or equal to
print(a <= b) # Less than or equal to


print("Hello" == "World")
print("Python" != "R")


print(True and True)
print(True and False)
print(False and False)


print(True and True)
print(True and False)

print(True and True and True and True)
print(True and True and True and False)
print(False or False or False or False)
print(False or False or False or True)


print(not True)


class Dog:

    def __init__(self, name, age, height):
        self.name = name
        self.age = age
        self.height = height

ozzy = Dog("Ozzy", 3, 30)
filou = Dog("Filou", 5, 65)

print(filou , ozzy)


class Dog:

    def __init__(self, name, age, height):
        self.name = name
        self.age = age
        self.height = height

    def __gt__(self,other):
        return self.height > other.height

ozzy = Dog("Ozzy", 3, 30)
filou = Dog("Filou", 5, 65)

print(filou , ozzy)
print(ozzy , filou)


a = 2
b = 3
c = 9

print(a ** b > 5 and c - a // b >= 9 or b ** 2 == c)


print(5 * 2 // 3)
# Out:
# 610
# Hello! Welcome.
# 100.0
# 6
# 0
# 512
# 90.0
# 7
# 3
# 10
# 2.5
# 25
# 2
# 1
# Hi, my name is Théo.
# 100
# 110
# 110
# 100
# False
# True
# False
# True
# False
# True
# False
# True
# True
# False
# False
# True
# False
# True
# False
# False
# True
# False
# <__main__.Dog object at 0x78e4540f74d0> <__main__.Dog object at 0x78e4540f7b90>
# <__main__.Dog object at 0x78e4540f7b90> <__main__.Dog object at 0x78e4633262a0>
# <__main__.Dog object at 0x78e4633262a0> <__main__.Dog object at 0x78e4540f7b90>
# True
# 3

# %% [markdown]
# # **Operator Precedence and Associativity List in Python**
# Consider following list of operator precedence and associativity in Python. It shows all operators from highest precedence to lowest precedence.
#
# () : Parentheses (highest precedence) -> Associativity: Left to right
# x[index], x[index:index] : Subscription, slicing -> Associativity: Left to right
#
# await x : Await expression
#
# ** : Exponentiation -> Associativity: Right to left
#
# +x, -x, ~x : Unary plus, unary minus, bitwise NOT -> Associativity: Right to left
#
# *, @, /, //, % : Multiplication, matrix multiplication, division, floor division, remainder -> Associativity: Left to right
#
# +, - : Addition and subtraction -> Associativity: Left to right
#
# <<, >> : Bitwise shifts -> Associativity: Left to right
#
# & : Bitwise AND -> Associativity: Left to right
#
# ^ : Bitwise XOR -> Associativity: Left to right
#
# | : Bitwise OR -> Associativity: Left to right
#
# in, not in, is, is not, <, <=, >, >=, !=, == : Comparisons, membership, identity tests -> Associativity: Left to right
#
# not x : Boolean NOT -> Associativity: Right to left
#
# and : Boolean AND -> Associativity: Left to right
#
# or : Boolean OR -> Associativity: Left to right
#
# if-else : Conditional expression -> Associativity: Right to left
#
# lambda : Lambda expression
#
# := : Assignment expression (Walrus operator) -> Associativity: Right to left
#
# Note: Parentheses () have highest precedence and can override default order. Some operators, like await and lambda, do not have associativity.
